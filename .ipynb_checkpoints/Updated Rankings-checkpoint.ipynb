# %%
import pandas as pd
from trueskill import Rating, quality_1vs1, rate_1vs1, quality, rate, global_env, choose_backend,  backends, setup
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
from IPython.display import display
from ipywidgets import widgets
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
#!pip install --upgrade pip
#!pip install ipywidgets
# !python --version
# Out:
# Python 2.7.10

# %%
get_teams_by_division(df)
# Out:
#       division  compID                               location        date  \
# 0           DI     799                            Deland, FL   2018-02-23
# 1           DI     799                            Deland, FL   2018-02-23
# 2           DI     799                            Deland, FL   2018-02-23
# 3           DI     799                            Deland, FL   2018-02-23
# 4           DI     799                            Deland, FL   2018-02-23
# 5           DI     799                            Deland, FL   2018-02-23
# 6           DI     799                            Deland, FL   2018-02-23
# 7           DI     799                            Deland, FL   2018-02-23
# 8           DI     799                            Deland, FL   2018-02-23
# 9           DI     799                            Deland, FL   2018-02-23
# 10          DI     800                           Deland, FL    2018-02-23
# 11          DI     800                           Deland, FL    2018-02-23
# 12          DI     800                           Deland, FL    2018-02-23
# 13          DI     800                           Deland, FL    2018-02-23
# 14          DI     800                           Deland, FL    2018-02-23
# 15          DI     800                           Deland, FL    2018-02-23
# 16          DI     800                           Deland, FL    2018-02-23
# 17          DI     800                           Deland, FL    2018-02-23
# 18          DI     800                           Deland, FL    2018-02-23
# 19          DI     800                           Deland, FL    2018-02-23
# 20          DI     800                           Deland, FL    2018-02-23
# 21          DI     800                           Deland, FL    2018-02-23
# 22          DI     800                           Deland, FL    2018-02-23
# 23          DI     800                           Deland, FL    2018-02-23
# 24          DI     800                           Deland, FL    2018-02-23
# 25          DI     800                           Deland, FL    2018-02-23
# 26          DI     800                           Deland, FL    2018-02-23
# 27          DI     800                           Deland, FL    2018-02-23
# 28          DI     800                           Deland, FL    2018-02-23
# 29          DI     800                           Deland, FL    2018-02-23
# ...        ...     ...                                    ...         ...
# 14594       DI    1872    Gulf Shores, Al (NCAA Championship)  2018-05-06
# 14595       DI    1872    Gulf Shores, Al (NCAA Championship)  2018-05-06
# 14596       DI    1872    Gulf Shores, Al (NCAA Championship)  2018-05-06
# 14597       DI    1872    Gulf Shores, Al (NCAA Championship)  2018-05-06
# 14598       DI    1872    Gulf Shores, Al (NCAA Championship)  2018-05-06
# 14599       DI    1872    Gulf Shores, Al (NCAA Championship)  2018-05-06
# 14602       DI    1872    Gulf Shores, Al (NCAA Championship)  2018-05-06
# 14603       DI    1872    Gulf Shores, Al (NCAA Championship)  2018-05-06
# 14600       DI    1872    Gulf Shores, Al (NCAA Championship)  2018-05-06
# 14601       DI    1872    Gulf Shores, Al (NCAA Championship)  2018-05-06
# 14604       DI    1872    Gulf Shores, Al (NCAA Championship)  2018-05-06
# 14605       DI    1872    Gulf Shores, Al (NCAA Championship)  2018-05-06
# 14606       DI    1872    Gulf Shores, Al (NCAA Championship)  2018-05-06
# 14607       DI    1872    Gulf Shores, Al (NCAA Championship)  2018-05-06
# 14608       DI    1873   Gulf Shores, Al (NCAA Championship)   2018-05-06
# 14609       DI    1873   Gulf Shores, Al (NCAA Championship)   2018-05-06
# 14610       DI    1873   Gulf Shores, Al (NCAA Championship)   2018-05-06
# 14611       DI    1873   Gulf Shores, Al (NCAA Championship)   2018-05-06
# 14612       DI    1873   Gulf Shores, Al (NCAA Championship)   2018-05-06
# 14613       DI    1873   Gulf Shores, Al (NCAA Championship)   2018-05-06
# 14614       DI    1873   Gulf Shores, Al (NCAA Championship)   2018-05-06
# 14615       DI    1873   Gulf Shores, Al (NCAA Championship)   2018-05-06
# 14618       DI    1873   Gulf Shores, Al (NCAA Championship)   2018-05-06
# 14619       DI    1873   Gulf Shores, Al (NCAA Championship)   2018-05-06
# 14616       DI    1873   Gulf Shores, Al (NCAA Championship)   2018-05-06
# 14617       DI    1873   Gulf Shores, Al (NCAA Championship)   2018-05-06
# 14620       DI    1873   Gulf Shores, Al (NCAA Championship)   2018-05-06
# 14621       DI    1873   Gulf Shores, Al (NCAA Championship)   2018-05-06
# 14622       DI    1873   Gulf Shores, Al (NCAA Championship)   2018-05-06
# 14623       DI    1873   Gulf Shores, Al (NCAA Championship)   2018-05-06
#
#               college first_name       last_name  position  result  \
# 0             Stetson      Carly         Perales         1       1
# 1             Stetson    Sunniva  Helland-Hansen         1       1
# 2             Stetson     Sammee          Thomas         2       1
# 3             Stetson      Darby            Dunn         2       1
# 4             Stetson     Quinci          Birker         3       1
# 5             Stetson    Rebecca          Ingram         3       1
# 6             Stetson     Rachel           Noble         4       1
# 7             Stetson   Samantha          Harris         4       1
# 8             Stetson    Katinka           Krahn         5       1
# 9             Stetson      Alexa      Richardson         5       1
# 10      Georgia State     Brooke          Weiner         1       0
# 11      Georgia State    Tiffany         Creamer         1       0
# 12     South Carolina        Ali          Denney         1       1
# 13     South Carolina    Shannon        Williams         1       1
# 14      Georgia State      Allie           Elson         2       0
# 15      Georgia State     Ashley          McGinn         2       0
# 16     South Carolina      Lydia           Dimke         2       1
# 17     South Carolina      Katie           Smith         2       1
# 18      Georgia State    Georgia         Johnson         3       0
# 19      Georgia State       Eden           Hawes         3       0
# 14604   17-21, 24-22, 15-8
# 14605   17-21, 24-22, 15-8
# 14606   17-21, 24-22, 15-8
# 14607   17-21, 24-22, 15-8
# 14608         21-18, 21-19
# 14609         21-18, 21-19
# 14610         21-18, 21-19
# 14611         21-18, 21-19
# 14612          21-19, 21-9
# 14613          21-19, 21-9
# 14614          21-19, 21-9
# 14615          21-19, 21-9
# 14618  21-15, 19-21, 15-12
# 14619  21-15, 19-21, 15-12
# 14616  21-15, 19-21, 15-12
# 14617  21-15, 19-21, 15-12
# 14620   17-21, 24-22, 15-8
# 14621   17-21, 24-22, 15-8
# 14622   17-21, 24-22, 15-8
# 14623   17-21, 24-22, 15-8
#
# [14624 rows x 10 columns]

# %%
df.columns
# Out:
# Index([u'division', u'compID', u'location', u'date', u'college', u'first_name',
#        u'last_name', u'position', u'result', u'score'],
#       dtype='object')

# %%
df = pd.read_csv('Data/Competition.csv').drop_duplicates()

# %%
sort_order = ['date', 'compID', 'position', 'result']

#UTILITIES
def strip_all_strings_in_df(df_, cols_):
    for s in cols_:
        df_[s] = df_[s].apply(lambda x: x.strip())
    return df_

#LOAD DATA
def get_competition_info(df_, div_='DI'):  
    df_ = get_teams_by_division(df_, div_)                                                      
    df_ = strip_all_strings_in_df(df_, ['first_name', 'last_name', 'college', 'location', 'division', 'score'])     
    df_ = df_.groupby('compID') \
        .filter(lambda x: len(x) == 20) \
        .sort_values(['date', 'compID', 'position', 'result'], ascending=True) \
        .reset_index() \
        .iloc[:,1:]
    return df_

#GET TEAM INFO
def get_teams_by_division(df_, div_='DI'):
    df_ = df_[df_["division"] == div_].drop_duplicates() \
        .reset_index().iloc[:,1:] \
        .sort_values(sort_order, ascending=True)
    return df_

#SETTING RATINGS
def set_default_player_rating(df_, div_='DI'): 
    df_players_ = df_.loc[:, ['division',  'college', 'first_name', 'last_name', 'mu', 'sigma']].copy() \
                    .drop_duplicates()
    df_players_ = strip_all_strings_in_df(df_players_, ['division',  'college', 'first_name', 'last_name'])
    df_players_ = df_players_[df_players_.division == div_]
    df_players_.loc[:,'mu'] = Rating().mu
    df_players_['sigma'] = Rating().sigma
    df_players_ = df_players_.sort_values(['last_name', 'first_name', 'college'], ascending=True) \
        .drop_duplicates() \
        .reset_index() \
        .loc[:, ['division',  'college', 'first_name', 'last_name',  'mu', 'sigma']]
    return df_players_


#GETTING RATINGS
def get_player_ratings_from_match(df_, fname_, lname_, college_):
    player_idx = df_[(df_.first_name == fname_) \
                 & (df_.last_name == lname_) \
                 & (df_.college == college_)].index
    my_mu = df_.iloc[player_idx.item(),  df_.columns.get_loc('mu')]
    my_sigma = df_.iloc[player_idx.item(),  df_.columns.get_loc('sigma')]
    my_rating = Rating(mu=my_mu, sigma=my_sigma)
    return my_rating


def set_player_ratings_after_match(df_, fname_, lname_, college_, position_,k_factor_, rating_):
    player_idx = df_[(df_.first_name == fname_) \
                 & (df_.last_name == lname_) \
                 & (df_.college == college_)].index
    df_.iloc[player_idx,  df_.columns.get_loc('mu')] = rating_.mu + k_factor_[int(position_)-1]
    #df_.iloc[player_idx,  df_.columns.get_loc('mu')] = rating_.mu
    df_.iloc[player_idx,  df_.columns.get_loc('sigma')] = rating_.sigma
    
    my_mu = df_.iloc[player_idx.item(),  df_.columns.get_loc('mu')]
    my_sigma = df_.iloc[player_idx.item(),  df_.columns.get_loc('sigma')]
    my_rating = Rating(mu=my_mu, sigma=my_sigma)
    return my_rating


def create_ratings_from_matches(df_, k_factor_=[0,0,0,0,0], div_='DI'):
    df_matches = get_competition_info(df_, div_)
    df_players = set_default_player_rating(df_, div_)

    groups = df_matches.groupby(['date', 'compID', 'position']).groups
    counter = 0
    hist_dict = {}

    for key, value in sorted(groups.iteritems()):
        r = {}
        r_new = {}
        
        for i in range(len(value)):
            fname = df_matches.iloc[value[i], df_matches.columns.get_loc('first_name')]
            lname = df_matches.iloc[value[i], df_matches.columns.get_loc('last_name')]
            college = df_matches.iloc[value[i], df_matches.columns.get_loc('college')]
            position = df_matches.iloc[value[i], df_matches.columns.get_loc('position')]
            r[i] = get_player_ratings_from_match(df_players, fname, lname, college)

        t1 = [r[0], r[1]]
        t2 = [r[2], r[3]]

        ((r_new[0], r_new[1]), (r_new[2], r_new[3])) = rate([t1,t2], ranks=[1,0])

        for j in range(4):
            fname = df_matches.iloc[value[j], df_matches.columns.get_loc('first_name')]
            lname = df_matches.iloc[value[j], df_matches.columns.get_loc('last_name')]
            college = df_matches.iloc[value[j], df_matches.columns.get_loc('college')]
            position = df_matches.iloc[value[j], df_matches.columns.get_loc('position')]
            set_player_ratings_after_match(df_players, \
                                           fname, \
                                           lname, \
                                           college, \
                                           position, \
                                           k_factor_, \
                                           Rating(mu=(r_new[j].mu +k_factor_[i]), sigma=r_new[j].sigma  )) 

        hist_dict[counter] = df_matches.iloc[value].merge(df_players, \
                                                          left_on=['first_name', 'last_name', 'college'], 
                                                          right_on=['first_name', 'last_name', 'college'], 
                                                          how='inner')
        counter += 1

    df_match_history = pd.concat(hist_dict.values(), axis=0) \
                        .sort_values(['date','compID'], ascending=True) \
                        .reset_index() \
                        .iloc[:,1:] \
                        .rename(columns={'division_y': 'division'})
    df_match_history['name'] = df_match_history['first_name'] + " " + df_match_history['last_name']
    
    
    df_match_history = set_primary_position( df_match_history)
    
    d = {'matches': df_matches, 'match_history': df_match_history, 'players':  df_players}
    return d

def set_primary_position(df_):
    df_['count_max'] = df_.groupby(['college', 'name', 'position'])['position'].transform('count')
    df_['count at primary position'] = df_.groupby(['college','name'])['count_max'].transform('max')
    idx = df_[df_['count at primary position'] == df_['count_max']]

    #primary_position = strip_all_strings_in_df(primary_position, ['college','name'])
    primary_position = idx.loc[:, ['college','name', 'position']]
    primary_position['position'] = primary_position.groupby(['name'])['position'].transform('min')
    primary_position = primary_position.drop_duplicates()

    temp = df_.merge(primary_position, on=['college', 'name'])
    temp.rename(columns = {'position_y': 'primary position', 'position_x': 'position'}, inplace=True)
    temp = temp.loc[:,['date','compID', 'location', 'first_name', 'last_name', 'name', \
          'position', 'primary position', 'college','division' ,'result', 'mu', 'sigma' ]]
    return temp


def plot_rating_distribution(df_):
    d = df_ \
        .sort_values('date', ascending=True) \
        .groupby(['first_name', 'last_name', 'college']) \
        .last() \
        .sort_values('mu', ascending=False) \
        .reset_index()

    current_palette = sns.color_palette()

    f =  plt.figure(figsize=(30, 15))
    grid = plt.GridSpec(3, 5, wspace=.4, hspace=0.3)
    summary_ax = f.add_subplot(grid[:2, 0:])
    pos_ax = [f.add_subplot(grid[2, 4+(i*-1)], xticklabels=[], sharey=summary_ax) for i in range(5)]
    [sns.distplot( d[d['primary position'] == i+1]['mu'], ax=summary_ax,  color=current_palette[i], axlabel='Rating', hist_kws=dict(alpha=.1)) for i in range(5)]
    [sns.distplot( d[d['primary position'] == i+1]['mu'], ax=pos_ax[i], color=current_palette[i], axlabel='Position '+str(i+1))  for i in range(5)]
    return d

def get_top_players(df_, position_='all'):
    if position_ == 'all':
        df_top_players_ = df_.sort_values(['date', 'compID'], ascending=True).copy()
    else:
        df_top_players_ = df_[df_['primary position'] == position_].sort_values(['date', 'compID'], ascending=True).copy()
    df_top_players_ = df_top_players_.groupby(['first_name', 'last_name', 'college', 'division']) \
                                    .last() \
                                    .sort_values('mu', ascending=False) \
                                    .reset_index()
        
    df_top_players_['rank'] = df_top_players_.index+1
    df_top_players_ = df_top_players_.loc[:,['rank','name', 'college', 'division', 'mu', 'primary position', 'date']]
    df_top_players_.columns= ['rank','name', 'college', 'division', 'rating', 'primary position' ,'date']
    return df_top_players_


def compare_rank_to_avca_all_americans(df_):
    view = get_top_players(df_)
    view[view.name.isin([
                        "Torrey Van Winden",
                        "Tia Miric",
                        "Federica Frasca",
                        "Margherita Bianchin",
                        "Victoria Paranagua",
                        "Vanessa Freire",
                        "Claire Coppola",
                        "Kristen Nuss",
                        "Madeline Mertz",
                        "Kaylie Mchugh",
                        "Megan McNamara",
                        "Nicole McNamara",
                        "Emily Maglio",
                        "Ka'iwi Schucht",
                        "Abril Bustamante",
                        "Tina Graudina",
                        "Lily Justine",
                        "Sarah Sponcil",
                        "Deahna Kraft",
                        "Corinne Quiggle",
                        "Nele Barber",
                        "Molly Turner",
    ])]

def get_player_rating(df, a):
    temp_df = df[df['name'] == a]
    r = Rating(temp_df.groupby(['mu'])['date'].last().sort_values(ascending=False).index[0], temp_df.groupby(['sigma'])['date'].last().sort_values(ascending=False).index[0])
    
    return     
def get_player_rating_history(df, a):
    temp_df = df[df['name'] == a]
    #print temp_df
    print a.upper()
    print "College: " + temp_df['college'].unique()[-1]
    print "Division: " + temp_df['division'].unique()[-1]
    print "Primary Position: " + str(temp_df['primary position'].unique()[-1])
    print "Last Rating:" + str(temp_df.groupby(['mu'])['date'].last().sort_values(ascending=False).index[0])
    f =  plt.figure(figsize=(30, 15))
    sns.lineplot(x="date", y="mu", data=temp_df)
    df_partner = pd.merge(df[df['name'] != a],temp_df, left_on=['compID', 'position', 'result'], right_on=['compID', 'position', 'result'] ) \
                    .groupby(['compID']) \
                    .first()
    df_partner.reset_index().set_index('compID')
    df_partner['Partner'] = df_partner['name_x']+' '+df_partner['mu_x'].apply(lambda x: '('+str(x)+ ')')
    df_partner = df_partner[['Partner']]
    df_summary = pd.merge(temp_df,df_partner, on='compID')
    return df_summary

def plot_team_players_history(df, college):
    df_team_history = df[df.college == college].sort_values('date', ascending=True)
    f =  plt.figure(figsize=(30, 15))
    #Not plotting correctly because the player plotted first may not have made it as far and chart is out of sequence
    for a in list(df_team_history.name.unique()):
        sns.lineplot(x="date", y="mu", data=df_team_history[df_team_history.name == a])

# %% [markdown]
# ## No Spread Factor Applied

# %%
d = create_ratings_from_matches(df, [0,0,0,0, 0])
rd = plot_rating_distribution(d['match_history'])
get_top_players(d['match_history'], position_='all').head(100).to_csv('000_000_000_000_000.csv')

# %% [markdown]
# ## Introduce overlap - Mike's requested spread factor

# %%
d = create_ratings_from_matches(df, [2.25, 1.7, 1.2, .75, .25])
rd = plot_rating_distribution(d['match_history'])
get_top_players(d['match_history'], position_='all').head(100).to_csv('225_170_120_075_025.csv')

# %% [markdown]
# ## Minimize spread factor, but keep overlap

# %%
d = create_ratings_from_matches(df, [1.1, .9, .5, .3, 0])
rd = plot_rating_distribution(d['match_history'])
get_top_players(d['match_history'], position_='all').head(100).to_csv('011_009_005_003_000.csv')

# %% [markdown]
# ## Between minimized spread factor and Sat night spread - add some points for flight 5

# %%
d = create_ratings_from_matches(df, [1.7, 1.2, .7, .45, .1])
rd = plot_rating_distribution(d['match_history'])
get_top_players(d['match_history'], position_='all').head(100).to_csv('170_120_070_045_010.csv')
# Out:
# /usr/local/anaconda3/envs/Conda3/lib/python2.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_top_players = get_top_players(d['match_history'], position_='all')

# %%
df_top_players
# Out:
#      rank                 name                           college division  \
# 0       1     Abril Bustamante                               USC       DI
# 1       2       Megan McNamara                              UCLA       DI
# 2       3      Nicole McNamara                              UCLA       DI
# 3       4         Emily Maglio                            Hawaii       DI
# 4       5       Ka'iwi Schucht                            Hawaii       DI
# 5       6        Tina Graudina                               USC       DI
# 6       7   Victoria Paranagua                     Florida State       DI
# 7       8       Claire Coppola                               LSU       DI
# 8       9         Kristen Nuss                               LSU       DI
# 9      10       Vanessa Freire                     Florida State       DI
# 10     11          Nele Barber                  Long Beach State       DI
# 11     12        Sasha Karelov                  Long Beach State       DI
# 12     13       Madeline Mertz                            Tulane       DI
# 13     14        Kaylie Mchugh                            Tulane       DI
# 14     15     Teegan Van Gunst                     Georgia State       DI
# 15     16          Katie Smith                    South Carolina       DI
# 16     17     Sunny Villapando                          Stanford       DI
# 17     18      Corinne Quiggle                        Pepperdine       DI
# 18     19         Deahna Kraft                        Pepperdine       DI
# 19     20      Federica Frasca                               FIU       DI
# 20     21  Margherita Bianchin                               FIU       DI
# 21     22        Mima Mirkovic                               Cal       DI
# 22     23     Annika Van Gunst                     Georgia State       DI
# 23     24       Jessica Wooten                   Houston Baptist       DI
# 24     25        Aeriel Horton                   Houston Baptist       DI
# 25     26         Rachel Nieto                  Long Beach State       DI
# 26     27         Lily Justine                              UCLA       DI
# 27     28        Sarah Sponcil                              UCLA       DI
# 28     29        Morgan Martin                            Hawaii       DI
# 29     30          Dani Barton                              Utah       DI
# ..    ...                  ...                               ...      ...
# 670   671             Sam Gott                               FAU       DI
# 671   672           Peri Green                               USC       DI
# 672   673      Olivia Petnicki                           Pacific       DI
# ...      ...         ...       ...
# 745        1   59.540262  3.291384
# 1021       1   48.593907  4.238493
# 1052       1   56.223777  3.472320
# 971        1   82.931323  3.586553
# 970        1   81.027891  3.647930
# 714        0   94.314002  2.989343
# 597        1   74.432544  3.737496
# 596        1   73.093064  3.790869
# 715        1   96.713531  2.943543
# 1053       1   57.330341  3.420946
# 747        1   61.661178  3.215064
# 972        1   84.582520  3.586832
# 822        1   78.773103  3.665125
# 716        1   98.943391  2.924827
# 1054       1   58.380444  3.382365
# 853        1   59.140261  3.350467
# 598        1   75.596442  3.732330
# 632        1  105.168027  3.000081
# 939        1   86.354097  3.562147
# 1023       1   50.318790  4.089829
# 854        1   61.377658  3.223726
# 2595       1   39.170566  4.308747
# 823        0   78.991286  3.537785
# 599        0   75.780158  3.597698
# 940        1   89.603565  3.411615
# 973        1   87.854222  3.433076
# 748        0   62.214704  3.154517
# 1055       0   58.896998  3.311568
# 633        1  109.003916  2.901406
# 717        1  102.695828  2.833581
#
# [340 rows x 13 columns]

# %%
plot_team_players_history(d['match_history'], 'South Carolina')  
df_top_players[df_top_players.college == 'South Carolina']
# Out:
#      rank              name         college division     rating  \
# 15     16       Katie Smith  South Carolina       DI  96.770154
# 43     44  Shannon Williams  South Carolina       DI  87.387569
# 44     45        Ali Denney  South Carolina       DI  87.387569
# 51     52       Cadie Bates  South Carolina       DI  84.341369
# 141   142   Carly Schneider  South Carolina       DI  64.696564
# 152   153    Julia Mannisto  South Carolina       DI  62.986831
# 189   190    Macie Tendrich  South Carolina       DI  59.581086
# 190   191        Leah Perri  South Carolina       DI  59.581086
# 359   360       Lydia Dimke  South Carolina       DI  45.202219
# 411   412      Aubrey Ezell  South Carolina       DI  41.919770
# 442   443    Caroline Skaff  South Carolina       DI  38.818933
# 468   469      Jess Vastine  South Carolina       DI  36.046250
# 486   487    Hannah Edelman  South Carolina       DI  34.922701
# 497   498   Franky Harrison  South Carolina       DI  34.642569
# 542   543       Avery Davis  South Carolina       DI  31.651495
# 664   665   Hannah Sorensen  South Carolina       DI  22.804682
#
#      primary position        date
# 15                  2  2018-05-04
# 43                  1  2018-05-04
# 44                  1  2018-05-04
# 51                  2  2018-05-04
# 141                 3  2018-05-04
# 152                 3  2018-05-04
# 189                 4  2018-05-04
# 190                 4  2018-05-04
# 359                 2  2018-05-04
# 411                 2  2018-04-14
# 442                 5  2018-04-22
# 468                 5  2018-04-22
# 486                 5  2018-03-17
# 497                 5  2018-05-04
# 542                 5  2018-03-31
# 664                 5  2018-02-23

# %%
plot_team_players_history(d['match_history'], 'Pepperdine')   
df_top_players[df_top_players.college == 'Pepperdine']
# Out:
#      rank              name     college division     rating  primary position  \
# 17     18   Corinne Quiggle  Pepperdine       DI  94.668937                 2
# 18     19      Deahna Kraft  Pepperdine       DI  94.668937                 2
# 39     40       Brook Bauer  Pepperdine       DI  87.642846                 1
# 40     41       Madalyn Roh  Pepperdine       DI  87.642846                 1
# 125   126    Gigi Hernandez  Pepperdine       DI  67.307688                 3
# 126   127        Heidi Dyer  Pepperdine       DI  67.307688                 3
# 155   156  Alexis Filippone  Pepperdine       DI  62.456411                 4
# 156   157     Skylar Caputo  Pepperdine       DI  62.456411                 4
# 300   301       Nikki Lyons  Pepperdine       DI  49.687981                 5
# 327   328     Maddie Dilfer  Pepperdine       DI  47.339166                 5
# 541   542       Katie Gavin  Pepperdine       DI  31.723809                 5
# 620   621    Jordan Ferrari  Pepperdine       DI  26.471933                 5
# 657   658      Kaity Bailey  Pepperdine       DI  23.136293                 5
#
#            date
# 17   2018-05-05
# 18   2018-05-05
# 39   2018-05-05
# 40   2018-05-05
# 125  2018-05-05
# 126  2018-05-05
# 155  2018-05-05
# 156  2018-05-05
# 300  2018-05-05
# 327  2018-05-05
# 541  2018-03-03
# 620  2018-03-11
# 657  2018-02-28

# %%
plot_team_players_history(d['match_history'], 'Hawaii')     
df_top_players[df_top_players.college == 'Hawaii']
# Out:
#      rank                 name college division      rating  primary position  \
# 3       4         Emily Maglio  Hawaii       DI  110.391574                 1
# 4       5       Ka'iwi Schucht  Hawaii       DI  110.391574                 1
# 28     29        Morgan Martin  Hawaii       DI   91.038288                 2
# 32     33        Lea Monkhouse  Hawaii       DI   89.379120                 2
# 60     61            Carly Kan  Hawaii       DI   82.125819                 3
# 70     71        Laurel Weaver  Hawaii       DI   80.278415                 3
# 121   122          Ari Homayun  Hawaii       DI   67.516901                 4
# 122   123             Amy Ozee  Hawaii       DI   67.516901                 4
# 247   248      Hannah Zalopany  Hawaii       DI   54.229599                 5
# 291   292        Paige Dreeuws  Hawaii       DI   50.417680                 5
# 418   419  Hi'ilawe Huddleston  Hawaii       DI   41.471596                 5
# 475   476    Allyssah Fitterer  Hawaii       DI   35.479442                 5
# 562   563        Chloe Luyties  Hawaii       DI   30.129411                 3
#
#            date
# 3    2018-05-06
# 4    2018-05-06
# 28   2018-05-06
# 32   2018-05-06
# 60   2018-05-06
# 70   2018-05-06
# 121  2018-05-06
# 122  2018-05-06
# 247  2018-05-06
# 291  2018-05-06
# 418  2018-04-15
# 475  2018-03-18
# 562  2018-03-20

# %%
plot_team_players_history(d['match_history'], 'UCLA')     
df_top_players[df_top_players.college == 'UCLA']
# Out:
#      rank             name college division      rating  primary position  \
# 1       2   Megan McNamara    UCLA       DI  111.475752                 1
# 2       3  Nicole McNamara    UCLA       DI  111.475752                 1
# 26     27     Lily Justine    UCLA       DI   91.582450                 2
# 27     28    Sarah Sponcil    UCLA       DI   91.582450                 2
# 93     94       Savvy Simo    UCLA       DI   72.918256                 3
# 124   125     Elise Zappia    UCLA       DI   67.481850                 4
# 142   143        Zana Muno    UCLA       DI   64.535900                 3
# 220   221       Izzy Carey    UCLA       DI   56.487923                 5
# 221   222      Megan Muret    UCLA       DI   56.487923                 5
# 231   232          Mac May    UCLA       DI   55.987476                 4
# 254   255     Madi Yeomans    UCLA       DI   53.512796                 3
# 571   572   Chanti Holroyd    UCLA       DI   29.299604                 5
# 580   581  Jamie McQuarrie    UCLA       DI   28.909420                 5
#
#            date
# 1    2018-05-06
# 2    2018-05-06
# 26   2018-05-06
# 27   2018-05-06
# 93   2018-05-06
# 124  2018-05-06
# 142  2018-05-06
# 220  2018-05-06
# 221  2018-05-06
# 231  2018-05-06
# 254  2018-04-28
# 571  2018-03-17
# 580  2018-03-17

# %%
plot_team_players_history(d['match_history'], 'Florida State') 
df_top_players[df_top_players.college == 'Florida State']
# Out:
#      rank                 name        college division      rating  \
# 6       7   Victoria Paranagua  Florida State       DI  109.003916
# 9      10       Vanessa Freire  Florida State       DI  102.695828
# 31     32         Katie Horton  Florida State       DI   89.603565
# 38     39          Hailey Luke  Florida State       DI   87.854222
# 73     74            Sara Putt  Florida State       DI   78.991286
# 79     80          Macy Jerger  Florida State       DI   75.780158
# 162   163       Brooke Kuhlman  Florida State       DI   62.214704
# 169   170  Francesca Goncalves  Florida State       DI   61.377658
# 201   202         Molly McBain  Florida State       DI   58.896998
# 292   293        Eva Torruella  Florida State       DI   50.318790
# 439   440  Madison Fitzpatrick  Florida State       DI   39.170566
# 464   465        Alaina Chacon  Florida State       DI   36.445578
# 520   521            Ali Eager  Florida State       DI   33.144551
# 550   551       Nikki Esposito  Florida State       DI   31.312706
#
#      primary position        date
# 6                   1  2018-05-05
# 9                   1  2018-05-05
# 31                  2  2018-05-05
# 38                  2  2018-05-05
# 73                  3  2018-05-05
# 79                  3  2018-05-05
# 162                 4  2018-05-05
# 169                 5  2018-05-05
# 201                 4  2018-05-05
# 292                 5  2018-04-22
# 439                 5  2018-05-05
# 464                 4  2018-04-15
# 520                 3  2018-04-14
# 550                 2  2018-04-15

# %%
df_top_players[df_top_players.college == 'Arizona']
# Out:
#      rank              name  college division     rating  primary position  \
# 41     42  Olivia Macdonald  Arizona       DI  87.591401                 1
# 42     43   Natalie Anselmo  Arizona       DI  87.591401                 1
# 140   141        Kacey Nady  Arizona       DI  64.794925                 2
# 153   154     Hailey Devlin  Arizona       DI  62.917853                 3
# 168   169   Stephany Purdue  Arizona       DI  61.463495                 3
# 206   207   Olivia Hallaran  Arizona       DI  58.023269                 2
# 224   225       Jonny Baham  Arizona       DI  56.397049                 4
# 250   251    Brooke Burling  Arizona       DI  54.210413                 4
# 256   257    Makenna Martin  Arizona       DI  53.378642                 5
# 374   375         Mia Mason  Arizona       DI  43.904751                 3
# 449   450   Caroline Cordes  Arizona       DI  38.276670                 5
# 511   512     Candice Denny  Arizona       DI  33.714247                 3
# 594   595     Sara Watanabe  Arizona       DI  28.352681                 5
#
#            date
# 41   2018-04-27
# 42   2018-04-27
# 140  2018-04-27
# 153  2018-04-27
# 168  2018-04-27
# 206  2018-04-27
# 224  2018-04-27
# 250  2018-04-27
# 256  2018-04-27
# 374  2018-03-31
# 449  2018-04-27
# 511  2018-02-25
# 594  2018-04-14

# %%
df_top_players[df_top_players.college == 'Long Beach State']
# Out:
#      rank                 name           college division      rating  \
# 10     11          Nele Barber  Long Beach State       DI  101.434937
# 11     12        Sasha Karelov  Long Beach State       DI  100.978356
# 567   568     Meagan Carter  Houston Baptist       DI  29.736040
# 589   590    Mikayla Vivens  Houston Baptist       DI  28.592337
#
#      primary position        date
# 23                  1  2018-04-22
# 24                  1  2018-04-22
# 128                 2  2018-04-22
# 129                 2  2018-04-22
# 341                 3  2018-04-22
# 342                 3  2018-04-22
# 368                 4  2018-04-22
# 408                 5  2018-04-22
# 507                 4  2018-04-22
# 561                 4  2018-04-14
# 567                 5  2018-04-14
# 589                 5  2018-04-22

# %%
df_top_players[df_top_players.college == 'FAU']
# Out:
#      rank                 name college division     rating  primary position  \
# 74     75    Carly Scarborough     FAU       DI  78.559317                 1
# 85     86         Amanda Silva     FAU       DI  75.443465                 1
# 107   108   Gabrielle Dischler     FAU       DI  69.798688                 2
# 108   109      Jessalyn Kinlaw     FAU       DI  69.798688                 2
# 151   152           Erica Brok     FAU       DI  63.021416                 3
# 203   204     Mackenzie Morris     FAU       DI  58.111655                 3
# 349   350         Kaila Dorish     FAU       DI  46.115906                 4
# 358   359       Nicole Navarro     FAU       DI  45.264721                 4
# 414   415      Julia Lewkowicz     FAU       DI  41.758359                 5
# 432   433  Brittany Pellitteri     FAU       DI  39.884319                 5
# 490   491        Megan McGrath     FAU       DI  34.842333                 3
# 492   493         Nicole Grant     FAU       DI  34.819646                 3
# 649   650    Ashlan Cunningham     FAU       DI  24.062737                 5
# 670   671             Sam Gott     FAU       DI  21.947564                 4
#
#            date
# 74   2018-04-21
# 85   2018-04-21
# 107  2018-04-21
# 108  2018-04-21
# 151  2018-04-21
# 203  2018-04-21
# 349  2018-04-21
# 358  2018-04-21
# 414  2018-04-21
# 432  2018-04-21
# 490  2018-03-25
# 492  2018-03-30
# 649  2018-03-30
# 670  2018-03-17

# %%
df_top_players[df_top_players.college == 'Stanford']
# Out:
#      rank                name   college division     rating  primary position  \
# 16     17    Sunny Villapando  Stanford       DI  95.836763                 1
# 66     67        Amelia Smith  Stanford       DI  81.646806                 2
# 67     68        Morgan Hentz  Stanford       DI  81.646806                 2
# 77     78      Courtney Bowen  Stanford       DI  76.543238                 3
# 139   140        Kate Formico  Stanford       DI  65.230185                 3
# 195   196     Kathryn Plummer  Stanford       DI  59.290967                 1
# 226   227    Catherine Raquel  Stanford       DI  56.222461                 3
# 279   280        Payton Chang  Stanford       DI  51.146952                 4
# 314   315       Caitlin Keefe  Stanford       DI  48.567323                 4
# 367   368         Blake Sharp  Stanford       DI  44.238793                 5
# 450   451  Shannon Richardson  Stanford       DI  37.998637                 5
# 568   569        Kat Anderson  Stanford       DI  29.567744                 5
#
#            date
# 16   2018-04-27
# 66   2018-04-27
# 67   2018-04-27
# 77   2018-04-27
# 139  2018-04-27
# 195  2018-03-27
# 226  2018-04-27
# 279  2018-04-27
# 314  2018-04-27
# 367  2018-04-27
# 450  2018-04-27
# 568  2018-04-26

# %% [markdown]
# ## Original Saturday night spread factor

# %%
d = create_ratings_from_matches(df, [2.2, 1.5, 1.1, .75, 0])
rd = plot_rating_distribution(d['match_history'])
get_top_players(d['match_history'], position_='all').head(100).to_csv('220_150_110_075_000.csv')

# %%
get_top_players(d['match_history'], position_='all')
# Out:
#      rank                 name                college division      rating  \
# 0       1     Abril Bustamante                    USC       DI  153.194999
# 1       2       Ka'iwi Schucht                 Hawaii       DI  140.021439
# 2       3         Emily Maglio                 Hawaii       DI  140.021439
# 3       4       Megan McNamara                   UCLA       DI  139.975159
# 4       5      Nicole McNamara                   UCLA       DI  139.975159
# 5       6   Victoria Paranagua          Florida State       DI  137.520625
# 6       7        Tina Graudina                    USC       DI  136.029994
# 7       8         Kristen Nuss                    LSU       DI  133.308954
# 8       9       Claire Coppola                    LSU       DI  133.308954
# 9      10       Vanessa Freire          Florida State       DI  129.650646
# 10     11          Nele Barber       Long Beach State       DI  127.800714
# 11     12       Madeline Mertz                 Tulane       DI  126.585954
# 12     13        Kaylie Mchugh                 Tulane       DI  126.585954
# 13     14        Sasha Karelov       Long Beach State       DI  126.075494
# 14     15     Teegan Van Gunst          Georgia State       DI  124.403999
# 15     16          Katie Smith         South Carolina       DI  121.576843
# 16     17        Mima Mirkovic                    Cal       DI  118.355247
# 17     18      Federica Frasca                    FIU       DI  118.211954
# 18     19  Margherita Bianchin                    FIU       DI  118.211954
# 19     20     Annika Van Gunst          Georgia State       DI  118.047401
# 20     21     Sunny Villapando               Stanford       DI  117.670100
# 21     22       Jessica Wooten        Houston Baptist       DI  117.001230
# 22     23        Aeriel Horton        Houston Baptist       DI  117.001230
# 23     24         Deahna Kraft             Pepperdine       DI  116.854267
# 24     25      Corinne Quiggle             Pepperdine       DI  116.854267
# 25     26         Rachel Nieto       Long Beach State       DI  116.465804
# 26     27        Morgan Martin                 Hawaii       DI  114.372826
# 27     28           Adore Anae                   Utah       DI  113.344974
# 28     29          Dani Barton                   Utah       DI  113.344974
# 29     30         Lily Justine                   UCLA       DI  113.188409
# ..    ...                  ...                    ...      ...         ...
# 670   671         Sydney Wicks  Cal State Bakersfield       DI   23.799177
# 671   672       Marissa Rogers                    UNF       DI   23.666636
# 672   673         Lauren Rokey         Morehead State       DI   23.607084
# 673   674        Helene Thelle                    FIU       DI   23.163220
# 674   675          Lexie Rawls      Abilene Christian       DI   23.040020
# 675   676      Hannah Sorensen         South Carolina       DI   23.030805
# 676   677          Maddie Beck         Missouri State       DI   23.017658
# 677   678       Sofia Resendiz      Abilene Christian       DI   22.994086
# 678   679    Mackenzie Rombach     Jacksonville State       DI   22.986695
# 679   680          Kayla Frear     Jacksonville State       DI   22.964089
# 680   681         Jordan Jones         Morehead State       DI   22.928690
# 681   682             Sam Gott                    FAU       DI   22.864178
# 682   683      Olivia Petnicki                Pacific       DI   22.705999
# 683   684         Maddie Fella         Morehead State       DI   22.671778
# 684   685    Danielle McCarson         Morehead State       DI   22.671778
# 685   686          Tori Reiser           Jacksonville       DI   22.661975
# 686   687      Makenzie Kesler      Abilene Christian       DI   22.446147
# 687   688           Peri Green                    USC       DI   22.163051
# 688   689        Morgan Esters                 Tulane       DI   21.893482
# 689   690      Peyton Boutwell      Abilene Christian       DI   21.893130
# 690   691        Sarah Stewart                 Mercer       DI   21.799191
# 691   692            Forfeit 2            Santa Clara       DI   21.274286
# 692   693            Forfeit 1            Santa Clara       DI   21.274286
# 693   694         Paris Cosley      Abilene Christian       DI   21.225219
# 694   695        Kellie Hughes               Portland       DI   20.800114
# 695   696      McKenna Webster                    ULM       DI   20.433601
# 696   697    Hannah Manzanares  Cal State Bakersfield       DI   20.361395
# 697   698          Haylie Beck       Coastal Carolina       DI   19.559371
# 698   699     Trish Koutsoukos                    USF       DI   19.353571
# 699   700       Brooke Boiseau  Cal State Bakersfield       DI   18.037423
#
#      primary position        date
# 0                   1  2018-05-05
# 1                   1  2018-05-06
# 2                   1  2018-05-06
# 3                   1  2018-05-06
# 4                   1  2018-05-06
# 5                   1  2018-05-05
# 6                   1  2018-05-05
# 7                   1  2018-05-04
# 8                   1  2018-05-04
# 9                   1  2018-05-05
# 10                  1  2018-04-28
# 11                  1  2018-04-21
# 12                  1  2018-04-21
# 13                  1  2018-04-28
# 14                  1  2018-04-21
# 15                  2  2018-05-04
# 16                  1  2018-04-28
# 17                  1  2018-05-04
# 18                  1  2018-05-04
# 19                  1  2018-04-21
# 20                  1  2018-04-27
# 21                  1  2018-04-22
# 22                  1  2018-04-22
# 23                  2  2018-05-05
# 24                  2  2018-05-05
# 25                  2  2018-04-28
# 26                  2  2018-05-06
# 27                  1  2018-04-27
# 28                  1  2018-04-27
# 29                  2  2018-05-06
# ..                ...         ...
# 670                 5  2018-04-28
# 671                 5  2018-03-03
# 672                 4  2018-04-02
# 673                 3  2018-03-16
# 674                 3  2018-03-10
# 675                 5  2018-02-23
# 676                 3  2018-03-02
# 677                 5  2018-04-22
# 678                 5  2018-03-24
# 679                 5  2018-04-20
# 680                 4  2018-04-20
# 681                 4  2018-03-17
# 682                 5  2018-03-03
# 683                 5  2018-04-20
# 684                 5  2018-04-20
# 685                 5  2018-04-14
# 686                 4  2018-03-10
# 687                 5  2018-03-18
# 688                 5  2018-03-24
# 689                 5  2018-02-24
# 690                 5  2018-03-17
# 691                 5  2018-04-20
# 692                 5  2018-04-20
# 693                 5  2018-04-22
# 694                 5  2018-03-12
# 695                 5  2018-03-16
# 696                 5  2018-03-24
# 697                 5  2018-04-14
# 698                 5  2018-03-10
# 699                 4  2018-04-21
#
# [700 rows x 7 columns]

# %% [markdown]
# ### Factor logic
# - Athletes who have never played in competition for the season, shouldn't show up in ranking. As soon as they compete in a match, their initial rating is 25
# - Athletes who have a win/loss record of less than 500 may have ratings lower than players who have never played in competition

# %%
def get_player_rating_history(df, a):
    temp_df = df[df['name'] == a]
    #print temp_df
    print a.upper()
    print "College: " + temp_df['college'].unique()[-1]
    print "Division: " + temp_df['division'].unique()[-1]
    print "Primary Position: " + str(temp_df['primary position'].unique()[-1])
    print "Last Rating:" + str(temp_df.groupby(['mu'])['date'].last().sort_values(ascending=False).index[0])
    f =  plt.figure(figsize=(30, 15))
    sns.lineplot(x="date", y="mu", data=temp_df)
    
    temp_df['opponent_result'] = abs(temp_df.result - 1)
    
    df_partner = pd.merge(df[df['name'] != a],temp_df, left_on=['compID', 'position', 'result'], right_on=['compID', 'position', 'result'] ) \
                    .groupby(['compID']) \
                    .first()
    df_partner.reset_index().set_index('compID')
    df_partner['Partner'] = df_partner['name_x']+' '+df_partner['mu_x'].apply(lambda x: '('+str(x)+ ')')
    df_partner = df_partner[['Partner']]
    
    df_summary = pd.merge(temp_df,df_partner, on='compID')
    
    df_opp = pd.merge(df[['name', 'mu' ,'compID', 'position', 'result']], \
                       temp_df[['compID', 'position', 'opponent_result']], 
                       left_on=['compID', 'position', 'result'], 
                       right_on=['compID', 'position', 'opponent_result']) \
                .groupby(['compID'])
    
    df_opp1 = df_opp.first().reset_index()[['compID','name', 'mu']]
    df_opp1['Opponent 1'] = df_opp1['name']+' '+df_opp1['mu'].apply(lambda x: '('+str(x)+ ')')
    df_opp2 = df_opp.last().reset_index()[['compID','name', 'mu']]
    df_opp2['Opponent 2'] = df_opp2['name']+' '+df_opp2['mu'].apply(lambda x: '('+str(x)+ ')')
    
    opp = pd.concat([df_opp1, df_opp2], axis=1)
    opp.columns = ['compID', 'name', 'mu', 'Opponent 1', 'compID1', 'name', 'mu','Opponent 2']
    opp = opp[['compID', 'Opponent 1', 'Opponent 2']]
    
    df_summary = pd.merge(df_summary,opp, on='compID')
    df_summary = df_summary[['date', 'compID', 'location', 'first_name', 'last_name', 'name', \
       'position', 'primary position', 'college', 'division', 'result', \
       'mu', 'sigma', 'Partner', 'Opponent 1', 'Opponent 2']] 
    
    return df_summary

a = 'Corinne Quiggle'
get_player_rating_history(d['match_history'], a)
# Out:
# CORINNE QUIGGLE
# College: Pepperdine
# Division: DI
# Primary Position: 2
# Last Rating:94.66893725948114
# /usr/local/anaconda3/envs/Conda3/lib/python2.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#           date  compID                         location first_name last_name  \
# 0   2018-02-23     818                      Phoenix, Az    Corinne   Quiggle
# 1   2018-02-24     825                      Phoenix, AZ    Corinne   Quiggle
# 2   2018-02-24     829                      Phoenix, AZ    Corinne   Quiggle
# 3   2018-02-28     876                  Los Angeles, Ca    Corinne   Quiggle
# 4   2018-02-28     877                  Los Angeles, Ca    Corinne   Quiggle
# 5   2018-02-28     879                  Los Angeles, CA    Corinne   Quiggle
# 6   2018-03-03     924                       Malibu, CA    Corinne   Quiggle
# 7   2018-03-03     929                       Malibu, CA    Corinne   Quiggle
# 8   2018-03-03     930                       Malibu, CA    Corinne   Quiggle
# 9   2018-03-07    1000                   Long Beach, Ca    Corinne   Quiggle
# 10  2018-03-10    1038              Manhattan Beach, Ca    Corinne   Quiggle
# 11  2018-03-10    1056              Manhattan Beach, Ca    Corinne   Quiggle
# 12  2018-03-11    1074              Manhattan Beach, Ca    Corinne   Quiggle
# 13  2018-03-11    1078              Manhattan Beach, Ca    Corinne   Quiggle
# 14  2018-03-14    1094                   Zuma Beach, Ca    Corinne   Quiggle
# 15  2018-03-17    1157                     Columbia, SC    Corinne   Quiggle
# 16  2018-03-17    1158                     Columbia, SC    Corinne   Quiggle
# 25             Tia Miric (78.914815783)    Torrey Van Winden (78.914815783)
# 26        Andie Shelton (60.4285654914)         Skylar Wine (64.3308111605)
# 27        Morgan Hughes (83.9908458961)         Payton Rund (83.9908458961)
# 28        Morgan Hughes (85.8624894209)         Payton Rund (85.8624894209)
# 29         Emily Maglio (110.311421071)      Ka'iwi Schucht (110.311421071)
# 30     Abril Bustamante (121.023633131)       Tina Graudina (109.197177726)

# %%
a = 'Brook Bauer'
get_player_rating_history(d['match_history'], a)
# Out:
# BROOK BAUER
# College: Pepperdine
# Division: DI
# Primary Position: 1
# Last Rating:87.642846319982
# /usr/local/anaconda3/envs/Conda3/lib/python2.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#           date  compID                         location first_name last_name  \
# 0   2018-02-23     818                      Phoenix, Az      Brook     Bauer
# 1   2018-02-24     825                      Phoenix, AZ      Brook     Bauer
# 2   2018-02-24     829                      Phoenix, AZ      Brook     Bauer
# 3   2018-02-28     876                  Los Angeles, Ca      Brook     Bauer
# 4   2018-02-28     877                  Los Angeles, Ca      Brook     Bauer
# 5   2018-02-28     879                  Los Angeles, CA      Brook     Bauer
# 6   2018-03-03     924                       Malibu, CA      Brook     Bauer
# 7   2018-03-03     929                       Malibu, CA      Brook     Bauer
# 8   2018-03-03     930                       Malibu, CA      Brook     Bauer
# 9   2018-03-07    1000                   Long Beach, Ca      Brook     Bauer
# 10  2018-03-10    1038              Manhattan Beach, Ca      Brook     Bauer
# 11  2018-03-10    1056              Manhattan Beach, Ca      Brook     Bauer
# 12  2018-03-11    1074              Manhattan Beach, Ca      Brook     Bauer
# 13  2018-03-11    1078              Manhattan Beach, Ca      Brook     Bauer
# 14  2018-03-14    1094                   Zuma Beach, Ca      Brook     Bauer
# 15  2018-03-17    1157                     Columbia, SC      Brook     Bauer
# 16  2018-03-17    1158                     Columbia, SC      Brook     Bauer
# 17  2018-03-18    1189                   Columbia, S.C.      Brook     Bauer
# 18  2018-03-18    1191                   Columbia, S.C.      Brook     Bauer
# 19  2018-03-27    1329                  Los Angeles, Ca      Brook     Bauer
# 20  2018-03-31    1416                   Zuma Beach, Ca      Brook     Bauer
# 21  2018-03-31    1421                   Zuma Beach, Ca      Brook     Bauer
# 22  2018-03-31    1428                   Zuma Beach, Ca      Brook     Bauer
# 23  2018-04-10    1589                  Los Angeles, Ca      Brook     Bauer
# 24  2018-04-14    1622                   Zuma Beach, Ca      Brook     Bauer
# 25  2018-04-14    1625                   Zuma Beach, Ca      Brook     Bauer
# 26  2018-04-20    1731                 Santa Monica, Ca      Brook     Bauer
# 27  2018-04-21    1770                 Santa Monica, Ca      Brook     Bauer
# 28  2018-04-21    1784  Santa Monica, Ca   (WCC Finals)      Brook     Bauer
# 29  2018-05-04    1866                  Gulf Shores, Al      Brook     Bauer
# 30  2018-05-05    1867                  Gulf Shores, Al      Brook     Bauer
#
#            name  position  primary position     college division  result  \
# 0   Brook Bauer         1                 1  Pepperdine       DI       0
# 1   Brook Bauer         2                 1  Pepperdine       DI       1
# 2   Brook Bauer         2                 1  Pepperdine       DI       1
# /usr/local/anaconda3/envs/Conda3/lib/python2.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %% [markdown]
# # Matchups -  Probability of wins

# %% [markdown]
# ### First get the probability of wins between two pairs

# %%
import itertools
import math
BETA = 4.167

def win_probability(team1_, team2_):
    delta_mu = sum(r.mu for r in team1_) - sum(r.mu for r in team2_)
    sum_sigma = sum(r.sigma ** 2 for r in itertools.chain(team1_, team2_))
    size = len(team1_) + len(team2_)
    denom = math.sqrt(size * (BETA * BETA) + sum_sigma)
    ts = global_env()
    return ts.cdf(delta_mu / denom)

#matches = d['match_history']
#matches[(matches.compID == 800) & (matches.position == 1)]

# %%
def get_pair_matchup_probability(df, player_list):
    t1p1 = Rating(get_player_rating(df, player_list[0]))
    t1p2 = Rating(get_player_rating(df, player_list[1]))
    t2p1 = Rating(get_player_rating(df, player_list[2]))
    t2p2 = Rating(get_player_rating(df, player_list[3]))

    return win_probability([t1p1,t1p2], [t2p1, t2p2])

get_pair_matchup_probability(d['match_history'], ['Abril Bustamante','Tina Graudina','Megan McNamara','Nicole McNamara'])
# Out:
# 0.7498237153052267

# %%
def predict_pair_matchup(df,player_list):
    p = get_pair_matchup_probability(df, player_list)
    if p > .55:
        t1 = 1
        t2 = 0
    elif p < .45:
        t1 = 0
        t2 = 1
    else:
        t1 = 0
        t2 = 0
    return t1, t2

predict_pair_matchup(d['match_history'], ['Abril Bustamante','Tina Graudina','Megan McNamara','Nicole McNamara'])
# Out:
# (1, 0)

# %%
df['name'] = df.first_name + " " + df.last_name

# %%
flight1 = ['Abril Bustamante','Tina Graudina','Megan McNamara','Nicole McNamara']
flight2 = df[(df.compID == 1873) & (df.position == 2)].sort_values(['position', 'college'])
flight2 = [a.strip() for a in flight2.name]

flight3 = df[(df.compID == 1873) & (df.position == 3)].sort_values(['position', 'college'])
flight3 = [a.strip() for a in flight3.name]
flight3

flight4 = df[(df.compID == 1873) & (df.position == 4)].sort_values(['position', 'college'])
flight4 = [a.strip() for a in flight4.name]
flight4

flight5 = df[(df.compID == 1873) & (df.position == 5)].sort_values(['position', 'college'])
flight5 = [a.strip() for a in flight5.name]
flight5

duel_dict = {1: flight1, 2: flight2, 3: flight3, 4:flight4, 5:flight5}
duel_dict.keys()
#predict_pair_matchup(d['match_history'], flight1), predict_pair_matchup(d['match_history'], flight3), predict_pair_matchup(d['match_history'], flight4), predict_pair_matchup(d['match_history'], flight5)
# Out:
# [1, 2, 3, 4, 5]

# %%
def predict_duel_matchup(df, duel_dict):
    t1 = 0
    t2 = 0
    for i in duel_dict.keys():
        temp_t = predict_pair_matchup(df, duel_dict[i])
        t1 += temp_t[0]
        t2 += temp_t[1]
    return t1, t2
predict_duel_matchup(d['match_history'], duel_dict)
# Out:
# (2, 3)

# %%
df_div1 = get_teams_by_division(df)
df_div1
# Out:
#       division  compID                               location        date  \
# 0           DI     799                            Deland, FL   2018-02-23
# 1           DI     799                            Deland, FL   2018-02-23
# 2           DI     799                            Deland, FL   2018-02-23
# 3           DI     799                            Deland, FL   2018-02-23
# 14617  21-15, 19-21, 15-12
# 14620   17-21, 24-22, 15-8
# 14621   17-21, 24-22, 15-8
# 14622   17-21, 24-22, 15-8
# 14623   17-21, 24-22, 15-8
#
# [14624 rows x 10 columns]

# %%
def predict_match(compid_, df_):
    r = {}
    v = {}
    t = {}
    
    match = df_[df_['compID'].astype(int) == compid_]
    counter = 0
    grouped = match.groupby(['date', 'compID', 'position'])
    
    for k in grouped.groups.keys():
        df_temp = grouped.get_group(k)
        df_temp = df_temp.sort_values('result', ascending=True)
        
        
        Rating(mu=p_lookup[i].mu, sigma=p_lookup[i].sigma)
        
        t1 = df_temp.head(2)
        
        #t[1] = [r[1], r[2]]
        #t[2] = [r[3], r[4]]
        
        #win_prob = win_probability(t[1], t[2])
    
    return df_temp.head(2)

matches = d['match_history']
predict_match(800, matches)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-0e97ed401854> in <module>()
#      25
#      26 matches = d['match_history']
# ---> 27 predict_match(800, matches)
#
# <ipython-input-42-0e97ed401854> in predict_match(compid_, df_)
#      13
#      14
# ---> 15         Rating(mu=p_lookup[i].mu, sigma=p_lookup[i].sigma)
#      16
#      17         t1 = df_temp.head(2)
#
# NameError: global name 'p_lookup' is not defined

# %% [markdown]
# # Preseason Rankings - non senior players
#
# Need team rosters

# %%
    for idx, rows in match.iterrows():
        r = {}
        p_lookup = {}
        t = {}
        for i in range(1,5):
            p_lookup[i] = lookup_player_rating(rows.iloc[i],[rows.iloc[5], rows.iloc[6]], df_player_rating )
            r[i] = Rating(mu=p_lookup[i].mu, sigma=p_lookup[i].sigma)
    
        t[1] = [r[1], r[2]]
        t[2] = [r[3], r[4]]
        
        win_prob = win_probability(t[1], t[2])
    
        
        match.loc[idx, 'Probability'] = win_prob 
        #print win_prob
        if (win_prob >.60):
            match.loc[idx, 'Predicted Winner'] = p_lookup[1]['Team'] 
            match.loc[idx, 'Distance From Draw'] = (win_prob - .60)
            match.loc[idx, 'T1 Win'] = 1
        elif (win_prob <.40):
            match.loc[idx, 'Predicted Winner'] = p_lookup[3]['Team'] 
            match.loc[idx, 'Distance From Draw'] = (.40-win_prob )
            match.loc[idx, 'T1 Win'] = 0
        else:
            match.loc[idx, 'Predicted Winner'] = 'Draw'
            match.loc[idx, 'Distance From Draw'] = 0
            match.loc[idx, 'T1 Win'] = .5

# %%
    groups = df_matches.groupby(['date', 'compID', 'position']).groups
    counter = 0
    hist_dict = {}

    for key, value in sorted(groups.iteritems()):
        r = {}
        r_new = {}
        
        for i in range(len(value)):
            fname = df_matches.iloc[value[i], df_matches.columns.get_loc('first_name')]
            lname = df_matches.iloc[value[i], df_matches.columns.get_loc('last_name')]
            college = df_matches.iloc[value[i], df_matches.columns.get_loc('college')]
            position = df_matches.iloc[value[i], df_matches.columns.get_loc('position')]
            r[i] = get_player_ratings_from_match(df_players, fname, lname, college)

        t1 = [r[0], r[1]]
        t2 = [r[2], r[3]]

        ((r_new[0], r_new[1]), (r_new[2], r_new[3])) = rate([t1,t2], ranks=[1,0])

        for j in range(4):
            fname = df_matches.iloc[value[j], df_matches.columns.get_loc('first_name')]
            lname = df_matches.iloc[value[j], df_matches.columns.get_loc('last_name')]
            college = df_matches.iloc[value[j], df_matches.columns.get_loc('college')]
            position = df_matches.iloc[value[j], df_matches.columns.get_loc('position')]
            set_player_ratings_after_match(df_players, \
                                           fname, \
                                           lname, \
                                           college, \
                                           position, \
                                           k_factor_, \
                                           Rating(mu=(r_new[j].mu +k_factor_[i]), sigma=r_new[j].sigma  ))

# %%
# Out:
#            date  compID    location first_name last_name              name  \
# 0    2018-02-23     800  Deland, FL    Tiffany   Creamer   Tiffany Creamer
# 37   2018-02-23     800  Deland, FL     Brooke    Weiner     Brooke Weiner
# 74   2018-02-23     800  Deland, FL        Ali    Denney        Ali Denney
# 107  2018-02-23     800  Deland, FL    Shannon  Williams  Shannon Williams
#
#      position  primary position         college division  result         mu  \
# 0           1                 2   Georgia State       DI       0  23.291677
# 37          1                 2   Georgia State       DI       0  23.291677
# 74          1                 1  South Carolina       DI       1  29.508323
# 107         1                 1  South Carolina       DI       1  29.508323
#
#         sigma
# 0    7.774363
# 37   7.774363
# 74   7.774363
# 107  7.774363

# %%
def actual_match(compid_, df_):
    return df_[df_['Compid'].astype(int) == compid_].groupby('Winner')['Position'].count()

actual_match(1863, df_matchups)

def predict_match(compid, df):
    match = df[df['Compid'].astype(int) == compid].copy().reset_index().iloc[:,1:]
    for idx, rows in match.iterrows():
        r = {}
        p_lookup = {}
        t = {}
        for i in range(1,5):
            p_lookup[i] = lookup_player_rating(rows.iloc[i],[rows.iloc[5], rows.iloc[6]], df_player_rating )
            r[i] = Rating(mu=p_lookup[i].mu, sigma=p_lookup[i].sigma)
            #match[i] = r[i]
    
        t[1] = [r[1], r[2]]
        t[2] = [r[3], r[4]]
        
        win_prob = win_probability(t[1], t[2])
    
        
        match.loc[idx, 'Probability'] = win_prob 
        #print win_prob
        if (win_prob >.60):
            match.loc[idx, 'Predicted Winner'] = p_lookup[1]['Team'] 
            match.loc[idx, 'Distance From Draw'] = (win_prob - .60)
            match.loc[idx, 'T1 Win'] = 1
        elif (win_prob <.40):
            match.loc[idx, 'Predicted Winner'] = p_lookup[3]['Team'] 
            match.loc[idx, 'Distance From Draw'] = (.40-win_prob )
            match.loc[idx, 'T1 Win'] = 0
        else:
            match.loc[idx, 'Predicted Winner'] = 'Draw'
            match.loc[idx, 'Distance From Draw'] = 0
            match.loc[idx, 'T1 Win'] = .5
        
    
    return match

_df = {}
temp = None
for a in range(780, 1870):
    print a,
    _df = predict_match(a, df_matchups)
    _df = pd.concat([_df, temp], axis=0)
    temp = _df


total_no_draw = len(_df[_df['Winner'] != 'Draw'])
accurate = len(_df[_df['Winner'] == _df['Predicted Winner']])
print accurate, total_no_draw, accurate*100/total_no_draw

_df

# %%
# Predict a Match

ef predictMatch(_compid, _df):
    _match = df_all_matchups[df_all_matchups['CompID'] == _compid].iloc[:,0:5]
    wins = {}

    for i in range(0,len(_match)):
        r = [Rating(lookupPlayerRating(_match.iloc[i,j], predict_ranking))  for j in range(1,5)]

        t1 = [r[0], r[1]]
        t2 = [r[2], r[3]]

        win_prob = win_probability(t1, t2)

        #print [(_match.iloc[i,j]+"("+lookupPlayer(_match.iloc[i,j], _df)['Team']+")") for j in range(1,5) ],

        if win_prob > .50:
            val = max(lookupPlayer(_match.iloc[i, 1], _df)['Team'], lookupPlayer(_match.iloc[i, 2], _df)['Team'])
            #print val, ' favored'
            try:
                wins[val] += 1
            except:
                wins[val] =  1
        elif win_prob < .50:
            val = max(lookupPlayer(_match.iloc[i, 3], _df)['Team'], lookupPlayer(_match.iloc[i, 4], _df)['Team'])
            #print val, ' favored'
            try:
                wins[val] += 1
            except:
                wins[val] =  1
        else:
            val = 'Draw'
            try:
                wins[val] += 1
            except:
                wins[val] =  1
                
    match_winner = max(wins.iteritems(), key=operator.itemgetter(1))[0]      
    
    return wins, match_winner

print "Predicted:" + str(predictMatch(1816, df_player_ratings))
print "Actual:" + str(actualMatch(1816, df_player_ratings))
