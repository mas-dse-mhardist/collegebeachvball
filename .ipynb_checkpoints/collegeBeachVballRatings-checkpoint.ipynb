# %%
import pandas as pd
from trueskill import Rating, quality_1vs1, rate_1vs1, quality, rate, global_env, choose_backend,  backends, setup
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
from IPython.display import display
from ipywidgets import widgets
display(HTML("<style>.container { width:90% !important; }</style>"))

sort_order = ['date', 'compID', 'position', 'result']
# Out:
# <style>.container { width:90% !important; }</style>

# %%
#UTILITIES
def strip_all_strings_in_df(df_, cols_):
    for s in cols_:
        df_[s] = df_[s].apply(lambda x: x.strip())
    return df_

#LOAD DATA
def get_competition_info(df_, div_='DI'):  
    df_ = get_teams_by_division(df_, div_)                                                      
    ### REMOVE SCORE FROM STRIP
    #df_ = strip_all_strings_in_df(df_, ['first_name', 'last_name', 'college', 'location', 'division', 'score'])
    df_ = strip_all_strings_in_df(df_, ['first_name', 'last_name', 'college', 'location', 'division'])
    df_['date'] = pd.to_datetime(df_['date'], errors = 'coerce')
    df_ = df_.groupby('compID') \
        .filter(lambda x: len(x) == 20) \
        .sort_values(['date', 'compID', 'position', 'result'], ascending=True) \
        .reset_index() \
        .iloc[:,1:]
    return df_

#GET TEAM INFO
def get_teams_by_division(df_, div_='DI'):
    df_ = df_[df_["division"] == div_].drop_duplicates() \
        .reset_index().iloc[:,1:] \
        .sort_values(sort_order, ascending=True)
    return df_

#SETTING RATINGS
def set_default_player_rating(df_, div_='DI',  dict_start_rating_ = None): 
    df_players_ = df_.loc[:, ['division',  'college', 'first_name', 'last_name', 'mu', 'sigma']].copy() \
                    .drop_duplicates()
    df_players_ = strip_all_strings_in_df(df_players_, ['division',  'college', 'first_name', 'last_name'])
    df_players_ = df_players_[df_players_.division == div_]
    df_players_.loc[:,'mu'] = Rating().mu
    df_players_['sigma'] = Rating().sigma
    
    #
    if dict_start_rating_ != None:
        df_players_['name'] = df_players_['first_name'] + " " + df_players_['last_name']
        df_players_['rating'] = df_players_['name'].replace(dict_start_ratings)
        df_players_['mu'] = df_players_['rating'].where(df_players_['rating'].isin([25,26,27,28,29])).fillna(25)
    #
    
    df_players_ = df_players_.sort_values(['last_name', 'first_name', 'college'], ascending=True) \
        .drop_duplicates() \
        .reset_index() \
        .loc[:, ['division',  'college', 'first_name', 'last_name',  'mu', 'sigma']]

    return df_players_


def create_start_rating(_adder_dict, _df_top_players):
    df_adder= pd.DataFrame.from_dict(_adder_dict, orient='index', columns=['adder']).reset_index()
    df_adder.columns = ['name', 'adder']
    df_starting_rating = pd.merge(_df_top_players, df_adder, how='outer')
    df_starting_rating['adder'] = df_starting_rating['adder'].fillna(0)
    df_starting_rating['start_rating'] = df_starting_rating['adder']+25
    df_starting_rating.columns = ['rank', 'name', 'college', 'division', 'last_season_end_rating',
       'primary position', 'date', 'adder', 'new_season_start_rating']
    return df_starting_rating[['name', 'last_season_end_rating','new_season_start_rating']]


#GETTING RATINGS
def get_player_ratings_from_match(df_, fname_, lname_, college_):
    player_idx = df_[(df_.first_name == fname_) \
                 & (df_.last_name == lname_) \
                 & (df_.college == college_)].index
    my_mu = df_.iloc[player_idx.item(),  df_.columns.get_loc('mu')]
    my_sigma = df_.iloc[player_idx.item(),  df_.columns.get_loc('sigma')]
    my_rating = Rating(mu=my_mu, sigma=my_sigma)
    return my_rating


def set_player_ratings_after_match(df_, fname_, lname_, college_, position_,k_factor_, rating_):
    player_idx = df_[(df_.first_name == fname_) \
                 & (df_.last_name == lname_) \
                 & (df_.college == college_)].index
    df_.iloc[player_idx,  df_.columns.get_loc('mu')] = rating_.mu + k_factor_[int(position_)-1]
    #df_.iloc[player_idx,  df_.columns.get_loc('mu')] = rating_.mu
    df_.iloc[player_idx,  df_.columns.get_loc('sigma')] = rating_.sigma
    
    my_mu = df_.iloc[player_idx.item(),  df_.columns.get_loc('mu')]
    my_sigma = df_.iloc[player_idx.item(),  df_.columns.get_loc('sigma')]
    my_rating = Rating(mu=my_mu, sigma=my_sigma)
    return my_rating



# TRACK RATINGS
def create_ratings_from_matches(df_, k_factor_=[0,0,0,0,0], div_='DI', dict_start_rating_ = None):
    sort_order = ['date', 'compID', 'position', 'result']
    df_matches = get_competition_info(df_, div_)
    df_players = set_default_player_rating(df_, div_, dict_start_rating_)
    
    groups = df_matches.groupby(['date', 'compID', 'position']).groups
    counter = 0
    hist_dict = {}

    for key in groups.keys():
        value = groups[key]
    
        r = {}
        r_new = {}
        
        for i in range(len(value)):
            fname = df_matches.iloc[value[i], df_matches.columns.get_loc('first_name')]
            lname = df_matches.iloc[value[i], df_matches.columns.get_loc('last_name')]
            college = df_matches.iloc[value[i], df_matches.columns.get_loc('college')]
            position = df_matches.iloc[value[i], df_matches.columns.get_loc('position')]
            r[i] = get_player_ratings_from_match(df_players, fname, lname, college)

        t1 = [r[0], r[1]]
        t2 = [r[2], r[3]]

        ((r_new[0], r_new[1]), (r_new[2], r_new[3])) = rate([t1,t2], ranks=[1,0])

        for j in range(4):
            fname = df_matches.iloc[value[j], df_matches.columns.get_loc('first_name')]
            lname = df_matches.iloc[value[j], df_matches.columns.get_loc('last_name')]
            college = df_matches.iloc[value[j], df_matches.columns.get_loc('college')]
            position = df_matches.iloc[value[j], df_matches.columns.get_loc('position')]
            set_player_ratings_after_match(df_players, \
                                           fname, \
                                           lname, \
                                           college, \
                                           position, \
                                           k_factor_, \
                                           Rating(mu=(r_new[j].mu +k_factor_[i]), sigma=r_new[j].sigma  )) 

        hist_dict[counter] = df_matches.iloc[value].merge(df_players, \
                                                          left_on=['first_name', 'last_name', 'college'], 
                                                          right_on=['first_name', 'last_name', 'college'], 
                                                          how='inner')
        counter += 1

    df_match_history = pd.concat(hist_dict.values(), axis=0) \
                        .sort_values(['date','compID'], ascending=True) \
                        .reset_index() \
                        .iloc[:,1:] \
                        .rename(columns={'division_y': 'division'})
    df_match_history['name'] = df_match_history['first_name'] + " " + df_match_history['last_name']
    
    
    df_match_history = set_primary_position( df_match_history)
    
    d = {'matches': df_matches, 'match_history': df_match_history, 'players':  df_players}
    return d


#Get player info
def set_primary_position(df_):
    df_['count_max'] = df_.groupby(['college', 'name', 'position'])['position'].transform('count')
    df_['count at primary position'] = df_.groupby(['college','name'])['count_max'].transform('max')
    idx = df_[df_['count at primary position'] == df_['count_max']]

    #primary_position = strip_all_strings_in_df(primary_position, ['college','name'])
    primary_position = idx.loc[:, ['college','name', 'position']]
    primary_position['position'] = primary_position.groupby(['name'])['position'].transform('min')
    primary_position = primary_position.drop_duplicates()

    temp = df_.merge(primary_position, on=['college', 'name'])
    temp.rename(columns = {'position_y': 'primary position', 'position_x': 'position'}, inplace=True)
    temp = temp.loc[:,['date','compID', 'location', 'first_name', 'last_name', 'name', \
          'position', 'primary position', 'college','division' ,'result', 'mu', 'sigma' ]]
    return temp

def get_top_players(df_, position_='all'):
    if position_ == 'all':
        df_top_players_ = df_.sort_values(['date', 'compID'], ascending=True).copy()
    else:
        df_top_players_ = df_[df_['primary position'] == position_].sort_values(['date', 'compID'], ascending=True).copy()
    df_top_players_ = df_top_players_.groupby(['first_name', 'last_name', 'college', 'division']) \
                                    .last() \
                                    .sort_values('mu', ascending=False) \
                                    .reset_index()
        
    df_top_players_['rank'] = df_top_players_.index+1
    df_top_players_ = df_top_players_.loc[:,['rank','name', 'college', 'division', 'mu', 'primary position', 'date']]
    df_top_players_.columns= ['rank','name', 'college', 'division', 'rating', 'primary position' ,'date']
    return df_top_players_

def get_player_rating(df, a):
    temp_df = df[df['name'] == a]
    r = Rating(temp_df.groupby(['mu'])['date'].last().sort_values(ascending=False).index[0], temp_df.groupby(['sigma'])['date'].last().sort_values(ascending=False).index[0])
    return r

def get_player_rating_history(df, a):
    temp_df = df[df['name'] == a]
    #print temp_df
    print(a.upper())
    print("College: " + temp_df['college'].unique()[-1])
    print("Division: " + temp_df['division'].unique()[-1])
    print("Primary Position: " + str(temp_df['primary position'].unique()[-1]))
    print("Last Rating:" + str(temp_df.groupby(['mu'])['date'].last().sort_values(ascending=False).index[0]))
    f =  plt.figure(figsize=(30, 15))
    sns.lineplot(x="date", y="mu", data=temp_df)
    
    temp_df['opponent_result'] = abs(temp_df.result - 1)
    
    df_partner = pd.merge(df[df['name'] != a],temp_df, left_on=['compID', 'position', 'result'], right_on=['compID', 'position', 'result'] ) \
                    .groupby(['compID']) \
                    .first()
    df_partner.reset_index().set_index('compID')
    df_partner['Partner'] = df_partner['name_x']+' '+df_partner['mu_x'].apply(lambda x: '('+str(x)+ ')')
    df_partner = df_partner[['Partner']]
    
    df_summary = pd.merge(temp_df,df_partner, on='compID')
    
    df_opp = pd.merge(df[['name', 'mu' ,'compID', 'position', 'result']], \
                       temp_df[['compID', 'position', 'opponent_result']], 
                       left_on=['compID', 'position', 'result'], 
                       right_on=['compID', 'position', 'opponent_result']) \
                .groupby(['compID'])
    
    df_opp1 = df_opp.first().reset_index()[['compID','name', 'mu']]
    df_opp1['Opponent 1'] = df_opp1['name']+' '+df_opp1['mu'].apply(lambda x: '('+str(x)+ ')')
    df_opp2 = df_opp.last().reset_index()[['compID','name', 'mu']]
    df_opp2['Opponent 2'] = df_opp2['name']+' '+df_opp2['mu'].apply(lambda x: '('+str(x)+ ')')
    
    opp = pd.concat([df_opp1, df_opp2], axis=1)
    opp.columns = ['compID', 'name', 'mu', 'Opponent 1', 'compID1', 'name', 'mu','Opponent 2']
    opp = opp[['compID', 'Opponent 1', 'Opponent 2']]
    
    df_summary = pd.merge(df_summary,opp, on='compID')
    df_summary = df_summary[['date', 'compID', 'location', 'first_name', 'last_name', 'name', \
       'position', 'primary position', 'college', 'division', 'result', \
       'mu', 'sigma', 'Partner', 'Opponent 1', 'Opponent 2']] 
    
    return df_summary

def plot_team_players_history(df, college):
    df_team_history = df[df.college == college].sort_values('date', ascending=True)
    playercount = len(df_team_history.name.unique())
    palette = sns.color_palette("husl", playercount)
    f =  plt.figure(figsize=(30, 15))
    sns.lineplot(data=df_team_history, x="date", y="mu", hue="name", \
                 style="primary position", markers=True, palette=palette,ci=None)
    
    
def get_prior_year_player_rating_adders(df_top_players_):
    #2 standard deviations from the mean - best performers
    two_sigma = 2*df_top_players_.rating.std() + df_top_players_.rating.mean()
    high_perfomers = df_top_players_[df_top_players_['rating'] > two_sigma][['name']]
    high_perfomers['adder'] = 2

    #3 standard deviations from the mean - over-performing outliers
    three_sigma = 3*df_top_players_.rating.std() + df_top_players_.rating.mean()
    ultra_high_perfomers = df_top_players_[df_top_players_['rating'] > three_sigma][['name']]
    ultra_high_perfomers['adder'] = 1

    adder = pd.concat([high_perfomers, ultra_high_perfomers])
    adder = adder.groupby(['name'])['adder'].sum().to_frame().sort_values(['adder'], ascending=False)
    adder_dict =  adder.to_dict()['adder']
    return adder_dict


# Plotting
def plot_rating_distribution(df_, save_path_=None):
    d = df_ \
        .sort_values('date', ascending=True) \
        .groupby(['first_name', 'last_name', 'college']) \
        .last() \
        .sort_values('mu', ascending=False) \
        .reset_index()

    current_palette = sns.color_palette()

    f =  plt.figure(figsize=(30, 15))
    grid = plt.GridSpec(3, 5, wspace=.4, hspace=0.3)
    summary_ax = f.add_subplot(grid[:2, 0:])
    pos_ax = [f.add_subplot(grid[2, 4+(i*-1)], xticklabels=[], sharey=summary_ax) for i in range(5)]
    [sns.distplot( d[d['primary position'] == i+1]['mu'], ax=summary_ax,  color=current_palette[i], axlabel='Rating', hist_kws=dict(alpha=.1)) for i in range(5)]
    [sns.distplot( d[d['primary position'] == i+1]['mu'], ax=pos_ax[i], color=current_palette[i], axlabel='Position '+str(i+1))  for i in range(5)]

    if save_path_ != None:
        f.savefig(save_path_)
        
    return d

def plot_top_player_rating_distribution(df_, save_path_=None):
    f =  plt.figure(figsize=(20, 7))
    sns.distplot( df_['rating'], hist_kws=dict(alpha=.1))
    #sns.lineplot( df_['rating'])
    print(df_['rating'].mean(), df_['rating'].std())
    pyplot.axvline(x=df_['rating'].mean())
    pyplot.axvline(x=df_['rating'].mean()+ df_['rating'].std(), linestyle='-.')
    pyplot.axvline(x=df_['rating'].mean()- df_['rating'].std(), linestyle='-.')
    pyplot.axvline(x=df_['rating'].mean()+ 2*df_['rating'].std(), linestyle='--')
    pyplot.axvline(x=df_['rating'].mean()- 2*df_['rating'].std(), linestyle='--')
    pyplot.axvline(x=df_['rating'].mean()+ 3*df_['rating'].std(), linestyle=':')

    if save_path_ != None:
        f.savefig(save_path_)
    return None

# %%
df_2018 = pd.read_csv('Data/Competition.csv').drop_duplicates()
df_2018[df_2018['last_name'] == 'Sponcil ']
# Out:
#       division  compID                               location        date  \
# 447         DI     832                           Honolulu, HI  2018-02-24
# 686         DI     844                           Honolulu, Hi  2018-02-24
# 1006        DI     860                           Honolulu, Hi  2018-02-25
# 1146        DI     868                           Honolulu, Hi  2018-02-25
# 1226        DI     876                       Los Angeles, Ca   2018-02-28
# 1246        DI     877                        Los Angeles, Ca  2018-02-28
# 1264        DI     878                       Los Angeles, CA   2018-02-28
# 2204        DI     925                             Malibu, CA  2018-03-03
# 2287        DI     929                             Malibu, CA  2018-03-03
# 3406        DI    1003                        Los Angeles, Ca  2018-03-08
# 3446        DI    1005                        Los Angeles, Ca  2018-03-08
# 4007        DI    1042                    Manhattan Beach, Ca  2018-03-10
# 4246        DI    1054                    Manhattan Beach, Ca  2018-03-10
# 4647        DI    1075                    Manhattan Beach, Ca  2018-03-11
# 4726        DI    1079                    Manhattan Beach, Ca  2018-03-11
# 6526        DI    1180                       Santa Monica, Ca  2018-03-17
# 6546        DI    1181                       Santa Monica, Ca  2018-03-17
# 6587        DI    1183                       Santa Monica, Ca  2018-03-17
# 7667        DI    1261                         Ocean Park, Ca  2018-03-24
# 7786        DI    1267                         Ocean Park, Ca  2018-03-24
# 8526        DI    1310                         Ocean Park, Ca  2018-03-25
# 8564        DI    1312                         Ocean Park, Ca  2018-03-25
# 8946        DI    1329                        Los Angeles, Ca  2018-03-27
# 9446        DI    1352                              Miami, Fl  2018-03-30
# 9506        DI    1357                             Miami, Fl   2018-03-30
# 9726        DI    1370                              Miami, Fl  2018-03-30
# 10327       DI    1402                              Miami, Fl  2018-03-31
# 10407       DI    1410                              Miami, Fl  2018-03-31
# 11326       DI    1463                        Los Angeles, Ca  2018-04-04
# 11385       DI    1466                        Los Angeles, Ca  2018-04-04
# 12202       DI    1522                          Stanford, Ca   2018-04-07
# 12222       DI    1523                          Stanford, Ca   2018-04-07
# 13260       DI    1579                          Stanford, Ca   2018-04-08
# 13280       DI    1580                          Stanford, Ca   2018-04-08
# 15441       DI    1712                         Long Beach, Ca  2018-04-19
# 17170       DI    1823                           Stanford, Ca  2018-04-26
# 17288       DI    1829                           Stanford, Ca  2018-04-27
# 17467       DI    1838                          Stanford, Ca   2018-04-28
# 17606       DI    1845                         Stanford, Ca    2018-04-28
# 17809       DI    1868                        Gulf Shores, Al  2018-05-05
# 17834       DI    1870                        Gulf Shores, Al  2018-05-05
# 17856       DI    1871           Gulf Shores, Al (NCAA Semis)  2018-05-06
# 17873       DI    1872    Gulf Shores, Al (NCAA Championship)  2018-05-06
# 17888       DI    1873   Gulf Shores, Al (NCAA Championship)   2018-05-06
#
#       college first_name last_name  position  result                    score
# 447      UCLA      Sarah  Sponcil          2       1             21-17, 21-13
# 686      UCLA      Sarah  Sponcil          2       0             21-19, 21-13
# 1006     UCLA      Sarah  Sponcil          2       1             21-16, 21-19
spread_factor_minimized = [1.1, .9, .5, .3, .05]
d_2017 = create_ratings_from_matches(df_2017, spread_factor_minimized)

plot_rating_distribution(d_2017['match_history'],'2017_110_090_050_030_005/rating_distribution.pdf')

df_top_players_2017 = get_top_players(d_2017['match_history'], position_='all')
df_top_players_2017.head(100).to_csv('2017_110_090_050_030_005/top_players.csv')
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
dict_adder_from_2017 = get_prior_year_player_rating_adders(df_top_players_2017)

# %%
df_start_rating_2018 = create_start_rating(dict_adder_from_2017, df_top_players_2017)
df_start_rating_2018.to_csv('2017_110_090_050_030_005/top_players_next_year_starting_rating.csv')


dict_start_ratings = df_start_rating_2018[['name','new_season_start_rating' ]].set_index('name').to_dict(orient='dict')['new_season_start_rating']
dict_start_ratings
# Out:
# {'Kelly Claes': 28.0,
#  'Sara Hughes': 28.0,
#  'Crissy Jones': 27.0,
#  'Federica Frasca': 27.0,
#  'Leigh Andrew': 27.0,
#  'Vanessa Freire': 27.0,
#  'Nicole McNamara': 27.0,
#  'Megan McNamara': 27.0,
#  'Savannah Slattery': 27.0,
#  'Brooke Kuhlman': 27.0,
#  'Sarah Sponcil': 27.0,
#  'Allie Wheeler': 27.0,
#  'Madalyn Roh': 27.0,
#  'Delaney Knudsen': 27.0,
#  'Lindsey Knudsen': 27.0,
#  'Payton Rund': 27.0,
#  'Tia Scambray': 27.0,
#  'Emily Sonny': 27.0,
#  'Hannah Hubbard': 27.0,
#  'Adlee Van Winden': 27.0,
#  'Adrianna Culbert': 27.0,
#  'Claire Coppola': 27.0,
#  'Kristen Nuss': 27.0,
#  'Jessalyn Kinlaw': 27.0,
#  'Margherita Bianchin': 27.0,
#  'Brittany Howard': 27.0,
#  'Corinne Quiggle': 27.0,
#  'Taylor Nelson': 27.0,
#  'Whitney Follette': 25.0,
#  'Bianca Arellano': 25.0,
#  'Sophie Bukovec': 25.0,
#  'Madison Witt': 25.0,
#  'Mckenna Witt': 25.0,
#  'Chelsea Ross': 25.0,
#  'Nele Barber': 25.0,
#  'Rachel Nieto': 25.0,
#  'Mikayla Tucker': 25.0,
#  'Morgan Martin': 25.0,
#  'Molly Turner': 25.0,
#  'Kristin Lind': 25.0,
#  'Darby Dunn': 25.0,
#  'Nicolette Martin': 25.0,
#  'Terese Cannon': 25.0,
#  'Katie Smith': 25.0,
#  'Tea Juric': 25.0,
#  'Kaylie Mchugh': 25.0,
#  'Megan Rice': 25.0,
#  'Nikki Taylor': 25.0,
#  'Maggie Skjelbred': 25.0,
#  'Delaney Rohan': 25.0,
#  'Tjasa Kotnik': 25.0,
#  "Ka'iwi Schucht": 25.0,
#  'Courtney Schwan': 25.0,
#  'Elise Zappia': 25.0,
#  'Lan Nguyen': 25.0,
#  'Taija Thomas': 25.0,
#  'Katie Hogan': 25.0,
#  'Kamila Tan': 25.0,
#  'Oluoma Okaro': 25.0,
#  'Madison Berridge': 25.0,
#  'Katie Lindelow': 25.0,
#  'Emmy Allen': 25.0,
#  'Emily Bible': 25.0,
#  'Sarah Chase': 25.0,
#  'Francesca Goncalves': 25.0,
#  'Victoria Paranagua': 25.0,
#  "Haley Pa'akaula": 25.0,
#  'Katarina Raicevic': 25.0,
#  'Courtney Miller': 25.0,
#  'Samantha Harris': 25.0,
#  'Madi Yeomans': 25.0,
#  'Madeline Mertz': 25.0,
#  'Izzy Carey': 25.0,
#  'Laurel Weaver': 25.0,
#  'Sasha Karelov': 25.0,
#  'Kobi Pekich': 25.0,
#  'Torrey Van Winden': 25.0,
#  'Nicole Lott': 25.0,
#  'Emily Maglio': 25.0,
#  'Aeriel Horton': 25.0,
#  'Jessica Wooten': 25.0,
#  'Tanna Aljoe': 25.0,
#  'Ali Denney': 25.0,
#  'Jaelyn Greene': 25.0,
#  'Amy Neal': 25.0,
#  'Toni Penrod': 25.0,
#  'Emily Krogman': 25.0,
#  'Mackenzie Allen': 25.0,
#  'Amanda Carroll': 25.0,
#  'Jenna Gray': 25.0,
#  'Kathryn Plummer': 25.0,
#  'Destiny Julye': 25.0,
#  'Anete Brinke': 25.0,
#  'Hayley Tippett': 25.0,
#  'Payton Chang': 25.0,
#  'Ivana Vanjak': 25.0,
#  'Heidi Dyer': 25.0,
#  'Skylar Caputo': 25.0,
#  'Macy Jerger': 25.0,
#  'Hailey Harward': 25.0,
#  'Natasa Savovic': 25.0,
#  'Tahleia Bishop': 25.0,
#  'Katie Zimmerman': 25.0,
#  'Macie Tendrich': 25.0,
#  'Hadley Swartz': 25.0,
#  'Olivia Macdonald': 25.0,
#  'Olivia Hallaran': 25.0,
#  'Olivia Powers': 25.0,
#  'Shannon Williams': 25.0,
#  'Candace Lacour': 25.0,
#  'Carly Kan': 25.0,
#  'Katie Friesen': 25.0,
#  'Cassie Strickland': 25.0,
#  'Sierra Sanchez': 25.0,
#  'Kori Simpson': 25.0,
#  'Ari Homayun': 25.0,
#  'Cristina Finan': 25.0,
#  'Emily Corrigan': 25.0,
#  'Ashley Glickert': 25.0,
#  'Giovanna Borgiotti': 25.0,
#  'Sara Kovac': 25.0,
#  'Jessie Prichard': 25.0,
#  'Riana Brennan': 25.0,
#  'Jordan Anderson': 25.0,
#  'Kaylee Anderson': 25.0,
#  'Megan Nash': 25.0,
#  'Maddie Ligon': 25.0,
#  'Dani Barton': 25.0,
#  'Kimberly Ferguson': 25.0,
#  'Carina Hoff': 25.0,
#  'Erika Zembyla': 25.0,
#  'Cati Leak': 25.0,
#  'Anika Wilson': 25.0,
#  'Deahna Kraft': 25.0,
#  'Katie Horton': 25.0,
#  'Heather Weiss': 25.0,
#  'Jessica Stansfield': 25.0,
#  'Joy Dennis': 25.0,
#  'Olivia Rodberg': 25.0,
#  'Avei Logoleo': 25.0,
#  'Jessica Gaffney': 25.0,
#  'Devanne Sours': 25.0,
#  'Lise Rugland': 25.0,
#  'Kayla Armer': 25.0,
#  'Tori Hinojosa': 25.0,
#  'Helene Thelle': 25.0,
#  'Jessica Fourspring': 25.0,
#  'Sophie Peel': 25.0,
#  'Raeann Greisen': 25.0,
#  'Stephanie Pollnow': 25.0,
#  'Emily Carroll': 25.0,
#  'Jazmine Barker': 25.0,
#  'Kate Elman': 25.0,
#  'Tarin Mergener': 25.0,
#  'Abril Bustamante': 25.0,
#  'Emma Peel': 25.0,
#  'Shayne Mcpherson': 25.0,
#  'Gabrielle Dischler': 25.0,
#  'Cassie House': 25.0,
#  'Ashley Kelsey': 25.0,
#  'Avery Hoven': 25.0,
#  'Annie Shurtz': 25.0,
#  'Camille Stepanof': 25.0,
#  'Mckala Rhodes': 25.0,
#  'Krissy Mummey': 25.0,
#  'Lyndi Scholl': 25.0,
#  'Allison Meehan': 25.0,
#  'Morgan Hentz': 25.0,
#  'Katie Will': 25.0,
#  'Lina Bernier': 25.0,
#  'Sara Little': 25.0,
#  'Carol Grasso': 25.0,
#  'Sarah Kelly': 25.0,
#  'Morgan Stanley': 25.0,
#  'Grace Campbell': 25.0,
#  'Ellyson Lundberg': 25.0,
#  'Kristine Hjembo': 25.0,
#  'Maddie Hills': 25.0,
#  'Alexis Salmons': 25.0,
#  'Kari Peterson': 25.0,
#  'Lexie Skalbeck': 25.0,
#  "Maddy O'Donnell": 25.0,
#  'Maddi Osburn': 25.0,
#  'Hailey Devlin': 25.0,
#  'Sunniva Helland-Hansen': 25.0,
#  'Emily Martinez': 25.0,
#  'Alexsa Parker': 25.0,
#  'Katelyn Carballo': 25.0,
#  'Jenna Belton': 25.0,
#  'Morgan Dees': 25.0,
#  'Bryce Bark': 25.0,
#  'Brittany Pellitteri': 25.0,
#  'Hailey Luke': 25.0,
#  'Katie Sato': 25.0,
#  'Julie Haake': 25.0,
#  'Sam Manley': 25.0,
#  'Brooke Weiner': 25.0,
#  'Brie Gathright': 25.0,
#  'Michaela Keefe': 25.0,
#  'Madeline Cannon': 25.0,
#  'Catherine Griffith': 25.0,
#  'Jensen Cunningham': 25.0,
#  'Charis Ludtke': 25.0,
#  'Tara Jenkins': 25.0,
#  'Chaney Howard': 25.0,
#  'Carly Dehoog': 25.0,
#  'Katie McCullough': 25.0,
#  'Nicole Navarro': 25.0,
#  'Nicole Grant': 25.0,
#  'Katherine Puisis': 25.0,
#  'Karissa Rhoades': 25.0,
#  'Megan Kruidhof': 25.0,
#  'Jenelle Hudson': 25.0,
#  'Megan Davenport': 25.0,
#  'Hannah Towne': 25.0,
#  'Brittnay Estes': 25.0,
#  'Kekai Whitford': 25.0,
#  'Jillian Bergeson': 25.0,
#  'Katrina Kernochan': 25.0,
#  'Maddy Kline': 25.0,
#  'Tiffany Creamer': 25.0,
#  'Tressa Buckland': 25.0,
#  'Emma Doud': 25.0,
#  'Veronica Nederend': 25.0,
#  'Bailey Choy': 25.0,
#  'LeeAnn Starr': 25.0,
#  'Carly Schneider': 25.0,
#  'Julia Mannisto': 25.0,
#  'Heather Schnars': 25.0,
#  'Lauren Gainer': 25.0,
#  'Kristen Mead': 25.0,
#  'Nora Buvarp Lavik': 25.0,
#  'Rebecca Conrad': 25.0,
#  'Savannah Niemen': 25.0,
#  'Emily Reed': 25.0,
#  'Hannah Zalopany': 25.0,
#  'Madi Wilcox': 25.0,
#  'Briana Correa': 25.0,
#  'Hannah Holmes': 25.0,
#  'Claire Crossfield': 25.0,
#  'Katarina Jovicic': 25.0,
#  'Victoria Corcoran': 25.0,
#  'Anabela Sataric': 25.0,
#  'Gabby Love': 25.0,
#  'Cara Sander': 25.0,
#  'Savvy Simo': 25.0,
#  'Mia Merino': 25.0,
#  'Rachel Noble': 25.0,
#  'Delaney Driver': 25.0,
#  'Nickeisha Williams': 25.0,
#  'Maddie Leiphardt': 25.0,
#  'Mia Mason': 25.0,
#  'Brooke Van Sickle': 25.0,
#  'Annika Albrecht': 25.0,
#  'Olivia Boender': 25.0,
#  'Melanie Wade': 25.0,
#  'Haven Hill': 25.0,
#  'Lindsey Vander Weide': 25.0,
#  'Megan Widener': 25.0,
#  'Molly Scheel': 25.0,
#  'Halli Amaro': 25.0,
#  'Jo Kremer': 25.0,
#  'Mackenzie Swan': 25.0,
#  'Lilly Kessler': 25.0,
#  'Kenley Adams': 25.0,
#  'Morea Wagner': 25.0,
#  'Eastyn Baleto': 25.0,
#  'Georgia Johnson': 25.0,
#  'Kate Novack': 25.0,
#  'Sarah Strasner': 25.0,
#  'Nikki Lyons': 25.0,
#  'Leigh Pudwill': 25.0,
#  'Sierra Nobley': 25.0,
#  'Sabryn Roberts': 25.0,
#  'Franky Harrison': 25.0,
#  'Estefanie Bethancourt': 25.0,
#  'Anna Gorman': 25.0,
#  'Emily Sullivan': 25.0,
#  'Janell Walley': 25.0,
#  'Julie Sam': 25.0,
#  'Amie Held': 25.0,
#  'Allison Kantor': 25.0,
#  'Marisa Doran': 25.0,
#  'Callan Molle': 25.0,
#  'Jordyn Sanchez': 25.0,
#  'Natalie Anselmo': 25.0,
#  'Danielle Faust': 25.0,
#  'Claire Waliczek': 25.0,
#  'Anna Crabtree': 25.0,
#  'Shelby Babowicz': 25.0,
#  'Shane Peters': 25.0,
#  'MC Rogers': 25.0,
#  'Jae-Lyn Visscher': 25.0,
#  'Nandyala Gama': 25.0,
#  'Kellen Dunn': 25.0,
#  'Ashley McGinn': 25.0,
#  'Justine Wong-Orantes': 25.0,
#  'Andie Malloy': 25.0,
#  'Sydney Alvis': 25.0,
#  'Ginny Gerig': 25.0,
#  'Natalia Giron': 25.0,
#  'Iya Lindahl': 25.0,
#  'Amy Ozee': 25.0,
#  'Nicole Anderson': 25.0,
#  'Sara Boothe': 25.0,
#  'Olivia Stasevich': 25.0,
#  'Brayden Gruenewald': 25.0,
#  'Ariah Palter': 25.0,
#  'Jade Vitt': 25.0,
#  'Katrin Gotterba': 25.0,
#  'Maycie LaBass': 25.0,
#  'Riley Young': 25.0,
#  'Caitlin Keefe': 25.0,
#  'Lily Justine': 25.0,
#  'Lexi Elman': 25.0,
#  'Andie Shelton': 25.0,
#  'Madison Woods': 25.0,
#  'Veronica Corcoran': 25.0,
#  'Mary Hernandez': 25.0,
#  'Rebecca Brown': 25.0,
#  'Jessica Clark': 25.0,
#  'Hannah Phillips': 25.0,
#  'Macy Catlett': 25.0,
#  'Hannah Meadows': 25.0,
#  'Allison Beckman': 25.0,
#  'Eva Torruella': 25.0,
#  'Madi Fitzsimmons': 25.0,
#  'Katie Davis': 25.0,
#  'Carly Perales': 25.0,
#  'Sarah Seiber': 25.0,
#  'Kristen Stucker': 25.0,
#  'Hannah Kirk': 25.0,
#  'Ciana Wagner': 25.0,
#  'Giulia Gavio': 25.0,
#  'Rachel Kuhn': 25.0,
#  'Kaity Bailey': 25.0,
#  'Jocelyn Rodriguez': 25.0,
#  'Nicole DeBolt': 25.0,
#  'Melissa Fuchs': 25.0,
#  'Claire Doyle': 25.0,
#  'Devon Rachel': 25.0,
#  'Jessica Johnson': 25.0,
#  "Gabby O'Connell": 25.0,
#  'Kennedy Madison': 25.0,
#  'Ashley Prater': 25.0,
#  'Cassidy Pickrell': 25.0,
#  'Sarita Mikals': 25.0,
#  'Erin Williams': 25.0,
#  'Natalie Wilson': 25.0,
#  'Bailey Banks': 25.0,
#  'Haley Jared': 25.0,
#  'Kalah Jones': 25.0,
#  'Kendra Dahlke': 25.0,
#  'Aeryn Owens': 25.0,
#  'Sarah Garrow': 25.0,
#  'Natalie Braun': 25.0,
#  'Blessing Dunn': 25.0,
#  'Nikki Hess': 25.0,
#  'Katja Ehlers': 25.0,
#  'Lauren Hollman': 25.0,
#  'Luiza Andrade': 25.0,
#  'Christina White': 25.0,
#  'Kelli Iverson': 25.0,
#  'Mia Rivera': 25.0,
#  'Camille Araujo': 25.0,
#  'Lauren Stivrins': 25.0,
#  'Kelly Hunter': 25.0,
#  'Avery Arellano': 25.0,
#  'Heather Pembroke': 25.0,
#  'Madison Green': 25.0,
#  'Taylor Foley': 25.0,
#  'Lauren Freed': 25.0,
#  'Brittany Pase': 25.0,
#  'Chanti Holroyd': 25.0,
#  'Shannon McPherson': 25.0,
#  'Brooke Burling': 25.0,
#  'Lana Brown': 25.0,
#  'Norene Iosia': 25.0,
#  'Kat Anderson': 25.0,
#  'Erin Indermill': 25.0,
#  'Lauren Durham': 25.0,
#  'Shannon Richardson': 25.0,
#  'Catherine Raquel': 25.0,
#  'Caroline Jordan': 25.0,
#  'Tyanna Roy': 25.0,
#  'Brigitte Murdock': 25.0,
#  'Holland Boege': 25.0,
#  'Lauren Twitty': 25.0,
#  'Tyler Lucas': 25.0,
#  'Courtney Bowen': 25.0,
#  'Jenna Panning': 25.0,
#  'Brook Frank': 25.0,
#  'Lindsey Calvin': 25.0,
#  'Jamie Hirai': 25.0,
#  'Julie Varga': 25.0,
#  'Rachel Evans': 25.0,
#  'Aleksandra Djuric': 25.0,
#  'Anna Chin': 25.0,
#  'Ashley Allmer': 25.0,
#  'Taylor Livoti': 25.0,
#  'Julia Warren': 25.0,
#  'Teya Neff': 25.0,
#  'Bridget Gustafson': 25.0,
#  'Bridget Odmark': 25.0,
#  'Molly McBain': 25.0,
#  'Adore Anae': 25.0,
#  'Lindsay Chalmers': 25.0,
#  'Carly Scarborough': 25.0,
#  'Raquel Rooney': 25.0,
#  'Cali Thompson': 25.0,
#  'Tani Stephens': 25.0,
#  'Emily Baptista': 25.0,
#  'Katey Merksamer': 25.0,
#  'Willow Johnson': 25.0,
#  'Maddy Silberger-Franek': 25.0,
#  'Kristen Castellanos': 25.0,
#  'Shannon Boyle': 25.0,
#  'Jizzyan Gesualdo': 25.0,
#  'Demi-Shay Watchorn': 25.0,
#  'Torre Glasker': 25.0,
#  'Madi Busler': 25.0,
#  'Maja Ristic': 25.0,
#  'Jasmine Hogan': 25.0,
#  'Remy Wilson': 25.0,
#  'Summer Avery': 25.0,
#  'Nikki Esposito': 25.0,
#  'Katie Barker': 25.0,
#  'Katie Krawczyk': 25.0,
#  'Sadie Anderson': 25.0,
#  'Holland Ponthieux': 25.0,
#  'Carly Lowry': 25.0,
#  'Carly Trueman': 25.0,
#  'Halie Werkmeister': 25.0,
#  'Taylor Agost': 25.0,
#  'Hannah McMahon': 25.0,
#  'Kimberly Schnars': 25.0,
#  'Hannah Troutman': 25.0,
#  'Bailey Smith': 25.0,
#  'Sydney Schuler': 25.0,
#  'Grace Convey': 25.0,
#  'Autumn Russell': 25.0,
#  'Gigi Hernandez': 25.0,
#  'Gretja Otten': 25.0,
#  "Hi'ilawe Huddleston": 25.0,
#  'Ashlan Cunningham': 25.0,
#  'Hope Rillema': 25.0,
#  'Victoria Spragg': 25.0,
#  'Katie Cross': 25.0,
#  'Bailey Nichol': 25.0,
#  'Kennedy Kurtz': 25.0,
#  'Mackenzie Dear': 25.0,
#  'Jaymee-Lee Bulda': 25.0,
#  'Laney Hayes': 25.0,
#  'Vanessa Richards': 25.0,
#  'Brittany Gilpin': 25.0,
#  'Emily Reinking': 25.0,
#  'Madi Wilkerson': 25.0,
#  'Courtney Dietrich': 25.0,
#  'Ali Eager': 25.0,
#  'Sarah Davis': 25.0,
#  "Sam D'Adamo": 25.0,
#  'Caroline Pomet': 25.0,
#  'Mackenzie Coates': 25.0,
#  'Brittney Munro': 25.0,
#  'Carla Cahill': 25.0,
#  "Madison O'Brien": 25.0,
#  'Taylor Poncetta': 25.0,
#  'Tiffany Thomas': 25.0,
#  'Jordan Terral': 25.0,
#  'Christina Mcafee': 25.0,
#  'Madison Kerr': 25.0,
#  'Morgan Smith': 25.0,
#  'Taylor Gruenewald': 25.0,
#  'Sarah Agnew': 25.0,
#  'August Raskie': 25.0,
#  'Leigh Stonerook': 25.0,
#  'Kenzie Maloney': 25.0,
#  'Mikaela Foecke': 25.0,
#  'Kate Federico': 25.0,
#  'Gabbi Moreno': 25.0,
#  'Amy South': 25.0,
#  'Dora Beilin': 25.0,
#  'Tiffany Morales': 25.0,
#  'Maddie Gordon': 25.0,
#  'Sienna Young': 25.0,
#  'Mackenzie Walker': 25.0,
#  'Kristey Markle': 25.0,
#  'Frances Giedraitis': 25.0,
#  'Sage Patchell': 25.0,
#  'Skyler Takeda': 25.0,
#  'Cecily Gable': 25.0,
#  'Marjolijn Oskam': 25.0,
#  'Julia Lewkowicz': 25.0,
#  'Maddie Cloutier': 25.0,
#  'Tatiana San Juan': 25.0,
#  'Michelle Gajdka': 25.0,
#  'Monica Gajda': 25.0,
#  'Danielle Pennington': 25.0,
#  'Julia Thompson': 25.0,
#  'Hannah Edelman': 25.0,
#  'Ronika Stone': 25.0,
#  'Maggie Scott': 25.0,
#  'Ariana Garner': 25.0,
#  'Kaylee Taff': 25.0,
#  'Danielle Wheeler': 25.0,
#  'Shayla Schmidt': 25.0,
#  'Taylor Laugero': 25.0,
#  'Hailey Lindberg': 25.0,
#  'Julia Golbeck': 25.0,
#  'Lauren Levy': 25.0,
#  'Breana Edwards': 25.0,
#  "Alex O'Sullivan": 25.0,
#  'Becca Dunn': 25.0,
#  'Abbie Harry': 25.0,
#  'Ana Ribeiro': 25.0,
#  'MiMi Arrington': 25.0,
#  'Morgan Carlson': 25.0,
#  'Bella Borgiotti': 25.0,
#  'Amber Gibson': 25.0,
#  'Brooke Smith': 25.0,
#  'Allie Elson': 25.0,
#  'Autumn Otto': 25.0,
#  'Djurdjina Milovic': 25.0,
#  'Kaitlan Krivdo': 25.0,
#  'Callie Jones': 25.0,
#  'Zoi Konstantopoulou': 25.0,
#  'Hailey Hughes': 25.0,
#  'Mallory Moran': 25.0,
#  'Madison Borowski': 25.0,
#  'Halle Hunt': 25.0,
#  'Brianna Doehrmann': 25.0,
#  'Chloe Crappell': 25.0,
#  'Hayley Gray': 25.0,
#  'Fabina Andrade': 25.0,
#  'Caroline Skaff': 25.0,
#  'Leah Hardeman': 25.0,
#  'Alli Evans': 25.0,
#  'Kwyn Johnson': 25.0,
#  'Kaitlynn Zdroik': 25.0,
#  'Rachel Noffsinger': 25.0,
#  'Sumeet Gill': 25.0,
#  'Tawnee Luafalemana': 25.0,
#  'Hannah Matt': 25.0,
#  'Erin Reineking': 25.0,
#  'Emma Hiller': 25.0,
#  'Dorina Klinger': 25.0,
#  'Lainy Thomas': 25.0,
#  'Natalie Wehner': 25.0,
#  'Tatiana Schlange': 25.0,
#  'Alex Holt': 25.0,
#  'Dane Miller': 25.0,
#  'Alyssa Kirkman': 25.0,
#  'Jeni Clark': 25.0,
#  'Anna Unnasch': 25.0,
#  'Beth Shoaff': 25.0,
#  'Samantha Uline': 25.0,
#  'Lauren Sproule': 25.0,
#  'Morgan Crawley': 25.0,
#  'Jamie Walsh': 25.0,
#  'Jessica Manley': 25.0,
#  'Mariana De Paula Silva': 25.0,
#  'Bethany Wedepohl': 25.0,
#  'Karli Baker': 25.0,
#  'Sam Gott': 25.0,
#  'Courtney Mullinax': 25.0,
#  'Morgan McDaniel': 25.0,
#  'Lauren Naatz': 25.0,
#  "Allie O'Reilly": 25.0,
#  'Marine Hall-Poirier': 25.0,
#  'Tiani Reeves': 25.0,
#  'Nicoletta Stork': 25.0,
#  'Nicolette Pinkney': 25.0,
#  'Sarah Savoca': 25.0,
#  'Hannah Lewis': 25.0,
#  'Kaitlyn Teeter': 25.0,
#  'Macy Reigelsperger': 25.0,
#  'Jemima Idemudia': 25.0,
#  'Mika Mierzwa': 25.0,
#  'Sydney Townsend': 25.0,
#  'Jennifer Hart': 25.0,
#  'Avie Niece': 25.0,
#  'Iva Mandic': 25.0,
#  'Chandler Clark': 25.0,
#  'Ashley Clingan': 25.0,
#  'Eliza Katoa': 25.0,
#  'Kelsee Felux': 25.0,
#  'Cailin Onosko': 25.0,
#  'Abigail Moss': 25.0,
#  'Dominique Cuellar': 25.0,
#  'Daniella Molinari': 25.0,
#  'Cassidy Rosso': 25.0,
#  'Lauren Page': 25.0,
#  'Kati Smith': 25.0,
#  'Madison Miller': 25.0,
#  'Liz Allen': 25.0,
#  'Morgan Robinson': 25.0,
#  'Taryn Griffey': 25.0,
#  'Jordan Jones': 25.0,
#  'Madeleine Doud': 25.0,
#  'Rhyan Rand': 25.0,
#  'Katty Workman': 25.0,
#  'Marina Chavez': 25.0,
#  'Kenna Hanses': 25.0,
#  'Skye Southwick': 25.0,
#  'Sydney Wicks': 25.0,
#  'Mary Kate Katarzynski': 25.0,
#  'Paige Swinney': 25.0,
#  'Breann Robinson': 25.0,
#  'Ciara Reistad': 25.0,
#  'April Adams': 25.0,
#  'Karlee Reynolds': 25.0,
#  'Ashley Slay': 25.0,
#  'Jackie Baro': 25.0,
#  'Alyssa Cecil': 25.0,
#  'Brianna Vega': 25.0,
#  'Cassedi Simon': 25.0,
#  'Jensen Allen': 25.0,
#  'Lela Mcintosh': 25.0,
#  'Jessie Wachtman': 25.0,
#  'Alexandria Thornton': 25.0,
#  'Molly Shonk': 25.0,
#  'Ally Barber': 25.0,
#  'Logan Carger': 25.0,
#  'Taylor Bradley': 25.0,
#  'Ashlyn Fleming': 25.0,
#  'Skylar Wine': 25.0,
#  'Claire Karsten': 25.0,
#  'Mattison Degarmo': 25.0,
#  'Janie Feldsher': 25.0,
#  'Haley Sobosle': 25.0,
#  'Emma Scanlan': 25.0,
#  'Laura Willems': 25.0,
#  'Megan Boudreaux': 25.0,
#  'Shelby Ladewig': 25.0,
#  'Berkeley Oblad': 25.0,
#  'Kate Ashman': 25.0,
#  'Shannon Levinson': 25.0,
#  'Alexa Richardson': 25.0,
#  'Katie Sullivan': 25.0,
#  'Jacqui Martin': 25.0,
#  'Thaliana Grajeda': 25.0,
#  'Dominque Dodd': 25.0,
#  'Olivia Canales': 25.0,
#  'Chelsea Red-Horse Mohl': 25.0,
#  'Madison Dueck': 25.0,
#  'Megan Lonhart': 25.0,
#  'Mary Lonhart': 25.0,
#  'Sarah Shaw': 25.0,
#  'Hannah Manzanares': 25.0,
#  'Marina Sanches': 25.0,
#  'Morgan Macgilvary': 25.0,
#  'Carly Beddingfield': 25.0,
#  'Ashlyne Miller': 25.0,
#  'Morgan Williams': 25.0,
#  'Brittney Markwith': 25.0,
#  'Emily Lopes': 25.0,
#  'Dora Lulic': 25.0,
#  'Kayla Tinker': 25.0,
#  'Rachel Perucki': 25.0,
#  'AJ Baumann': 25.0,
#  'Allyson Zuhlke': 25.0,
#  'Sydney Palmer': 25.0,
#  'Tyler Spriggs': 25.0,
#  'Kristyn Nicholson': 25.0,
#  'Ngozi Nwabuzoh': 25.0,
#  'Maddie Fella': 25.0,
#  'Naomi Overstreet': 25.0,
#  'Tori Reiser': 25.0,
#  'forfeit 2': 25.0,
#  'Mackenzie Rombach': 25.0,
#  'Saphyra Coombs-James': 25.0,
#  'Forfeit 1': 25.0,
#  'Morgan Walters': 25.0,
#  'Danielle McCarson': 25.0,
#  'Montana Green': 25.0,
#  'Trish Koutsoukos': 25.0,
#  'Emily Twohig': 25.0,
#  'Kelly Lean': 25.0}

# %%
plot_top_player_rating_distribution(df_top_players_2017, '2017_110_090_050_030_005/top_players_rating_distribution.pdf')
# Out:
# 40.82093486738036 14.56642538308233

# %% [markdown]
# ## Process 2018

# %%
df_2018 = pd.read_csv('Data/Competition.csv').drop_duplicates()
df_2018.columns = ['division', 'compID', 'location', 'date', 'college', 'first_name', 'last_name', 'position', 'result', 'score']

# %%
d_2018 = create_ratings_from_matches(df_2018, spread_factor_minimized, 'DI', dict_start_ratings)
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
d_2018 = create_ratings_from_matches(df_2018, spread_factor_minimized, 'DI', dict_start_ratings)

# %%
# !mkdir 2018_110_090_050_030_005
plot_rating_distribution(d_2018['match_history'],'2018_110_090_050_030_005/rating_distribution.pdf')

df_top_players_2018 = get_top_players(d_2018['match_history'], position_='all')
df_top_players_2018.head(100).to_csv('2018_110_090_050_030_005/top_players.csv')
df_top_players_2018
# Out:
# mkdir: 2018_110_090_050_030_005: File exists
#      rank                 name                           college division  \
# 0       1     Abril Bustamante                               USC       DI
# 1       2      Nicole McNamara                              UCLA       DI
# 2       3       Megan McNamara                              UCLA       DI
# 3       4        Tina Graudina                               USC       DI
# 4       5   Victoria Paranagua                     Florida State       DI
# 5       6       Ka'iwi Schucht                            Hawaii       DI
# 6       7         Emily Maglio                            Hawaii       DI
# 7       8         Kristen Nuss                               LSU       DI
# 8       9       Claire Coppola                               LSU       DI
# 9      10        Sasha Karelov                  Long Beach State       DI
# 10     11       Vanessa Freire                     Florida State       DI
# 11     12          Nele Barber                  Long Beach State       DI
# 12     13        Kaylie Mchugh                            Tulane       DI
# 13     14       Madeline Mertz                            Tulane       DI
# 14     15        Sarah Sponcil                              UCLA       DI
# 15     16      Corinne Quiggle                        Pepperdine       DI
# 16     17     Sunny Villapando                          Stanford       DI
# 17     18          Katie Smith                    South Carolina       DI
# 18     19         Lily Justine                              UCLA       DI
# 19     20        Morgan Martin                            Hawaii       DI
# 20     21         Deahna Kraft                        Pepperdine       DI
# 21     22         Katie Horton                     Florida State       DI
# 22     23         Rachel Nieto                  Long Beach State       DI
# 23     24     Teegan Van Gunst                     Georgia State       DI
# 24     25        Lea Monkhouse                            Hawaii       DI
# 25     26         Sammy Slater                               USC       DI
# 26     27          Hailey Luke                     Florida State       DI
# 673  19.539799                 5 2018-04-20
# 674  19.457739                 5 2018-03-28
# 675  19.393197                 4 2018-04-20
# 676  19.316067                 5 2018-04-20
# 677  19.316067                 5 2018-04-20
# 678  19.198565                 5 2018-04-13
# 679  19.198565                 5 2018-04-13
# 680  19.074339                 5 2018-04-14
# 681  18.824940                 5 2018-04-20
# 682  18.775254                 3 2018-03-10
# 683  18.739052                 5 2018-04-20
# 684  18.739052                 5 2018-04-20
# 685  18.686984                 5 2018-03-12
# 686  18.681530                 5 2018-03-24
# 687  18.632598                 5 2018-03-16
# 688  18.618157                 4 2018-04-02
# 689  18.550703                 5 2018-04-20
# 690  18.465522                 5 2018-04-28
# 691  18.455635                 4 2018-03-10
# 692  18.421533                 5 2018-03-10
# 693  17.710655                 4 2018-04-21
# 694  17.683433                 5 2018-04-14
# 695  17.466395                 4 2018-03-16
# 696  17.009353                 4 2018-04-20
# 697  16.795113                 5 2018-04-22
# 698  16.547452                 5 2018-04-22
# 699  14.359015                 5 2018-04-20
#
# [700 rows x 7 columns]

# %%
plot_top_player_rating_distribution(df_top_players_2018, '2018_110_090_050_030_005/top_players_rating_distribution.pdf')
# Out:
# 41.21114996762253 15.192079420063184

# %%
# Out:
#     division                           college first_name   last_name    mu  \
# 0         DI                      Jacksonville    Forfeit           1  25.0
# 1         DI                       Santa Clara    Forfeit           1  25.0
# 2         DI                      Jacksonville    Forfeit           2  25.0
# 3         DI                       Santa Clara    Forfeit           2  25.0
# 4         DI                  Long Beach State   Kristyna  Adamcikova  25.0
# 5         DI                               UAB     Kenley       Adams  25.0
# 6         DI                            Oregon     Taylor       Agost  25.0
# 7         DI                          Nebraska     Annika    Albrecht  25.0
# 8         DI                               LSU       Emmy       Allen  25.0
# 9         DI                       Boise State     Jensen       Allen  25.0
# 10        DI                    Morehead State        Liz       Allen  25.0
# 11        DI                              FGCU  Mackenzie       Allen  25.0
# 12        DI                               LSU     Ashley      Allmer  25.0
# 13        DI                              Utah      Adore        Anae  25.0
# 14        DI                        Washington     Jordan    Anderson  25.0
# 15        DI                          Stanford        Kat    Anderson  25.0
# 16        DI                Jacksonville State      Sadie    Anderson  25.0
# 17        DI                      Cal Poly SLO       Sjea    Anderson  25.0
# 18        DI         San Jose State University      Luiza     Andrade  25.0
# 19        DI  Cal State University, Sacramento     Cianna     Andrews  25.0
# 20        DI                           Arizona    Natalie     Anselmo  25.0
# 21        DI                               USF    Camille      Araujo  25.0
# 22        DI                               TCU      Avery    Arellano  25.0
# 23        DI                   Houston Baptist      Kayla       Armer  25.0
# 24        DI                    UNC Wilmington       Kyla   Augustine  25.0
# 25        DI         San Jose State University     Summer       Avery  25.0
# 26        DI                      Jacksonville     Shelby    Babowicz  25.0
# 27        DI                           Arizona      Jonny       Baham  25.0
# 28        DI                        Pepperdine      Kaity      Bailey  25.0
# 29        DI                        Washington       Kara      Bajema  25.0
# ..       ...                               ...        ...         ...   ...
# 670       DI                     Georgia State     Brooke      Weiner  25.0
# 671       DI                 Abilene Christian        Amy       Weiss  25.0
# 672       DI                               TCU     Jordan  Westendorf  25.0
# 673       DI                   Houston Baptist   Danielle     Wheeler  25.0
# 674       DI                              FGCU      Kayla   Whetstone  25.0
# 675       DI                               LMU      Kekai    Whitford  25.0
# 676       DI             Cal State Bakersfield     Sydney       Wicks  25.0
# 677       DI                               TCU     Kristy      Wieser  25.0
# 678       DI                      Saint Mary's       Madi   Wilkerson  25.0
# 679       DI                Jacksonville State      Katie        Will  25.0
# 680       DI                          Portland      Carey    Williams  25.0
# 681       DI              Cal State Northridge  Nickeisha    Williams  25.0
# 682       DI                    South Carolina    Shannon    Williams  25.0
# 683       DI                        New Mexico      Abbey      Wilson  25.0
# 684       DI                  Coastal Carolina      Kinga    Windisch  25.0
# 685       DI                           Pacific     Skylar        Wine  25.0
# 686       DI                            Mercer     Emilee    Wissmach  25.0
# 687       DI                               ASU       Kara     Woodard  25.0
# 688       DI                   Houston Baptist    Jessica      Wooten  25.0
# 689       DI                               UNF     Callie     Workman  25.0
# 690       DI                    Missouri State     Lynsey      Wright  25.0
# 691       DI                              UCLA       Madi     Yeomans  25.0
# 692       DI                               LSU     Kahlee        York  25.0
# 693       DI          Texas A&M Corpus Christi     Rachel       Young  25.0
# 694       DI                               LSU      Riley       Young  25.0
# 695       DI                      Saint Mary's     Sienna       Young  25.0
# 696       DI                            Hawaii     Hannah    Zalopany  25.0
# 697       DI                              UCLA      Elise      Zappia  25.0
# 698       DI         San Jose State University   Kaitlynn      Zdroik  25.0
# 699       DI                               FIU      Erika     Zembyla  25.0
#
#         sigma
# 0    8.333333
# 1    8.333333
# 2    8.333333
# 3    8.333333
# 4    8.333333
# 5    8.333333
# 6    8.333333
# 7    8.333333
# 8    8.333333
# 9    8.333333
# 10   8.333333
# 11   8.333333
# 12   8.333333
# 13   8.333333
# 14   8.333333
# 15   8.333333
# 16   8.333333
# 17   8.333333
# 18   8.333333
# 19   8.333333
# 20   8.333333
# 21   8.333333
# 22   8.333333
# 23   8.333333
# 24   8.333333
# 25   8.333333
# 26   8.333333
# 27   8.333333
# 28   8.333333
# 29   8.333333
# ..        ...
# 670  8.333333
# 671  8.333333
# 672  8.333333
# 673  8.333333
# 674  8.333333
# 675  8.333333
# 676  8.333333
# 677  8.333333
# 678  8.333333
# 679  8.333333
# 680  8.333333
# 681  8.333333
# 682  8.333333
# 683  8.333333
# 684  8.333333
# 685  8.333333
# 686  8.333333
# 687  8.333333
# 688  8.333333
# 689  8.333333
# 690  8.333333
# 691  8.333333
# 692  8.333333
# 693  8.333333
# 694  8.333333
# 695  8.333333
# 696  8.333333
# 697  8.333333
# 698  8.333333
# 699  8.333333
#
# [700 rows x 6 columns]

# %%
#df_matches

d_2018['match_history'][(d_2018['match_history']['compID'] > 1870) ]
# Out:
#             date  compID                      location first_name  last_name  \
# 106   2018-05-04    1874               Gulf Shores, Al        Ali     Denney
# 139   2018-05-04    1874               Gulf Shores, Al    Shannon   Williams
# 193   2018-05-04    1874               Gulf Shores, Al      Lydia      Dimke
#
#                                 Opponent 2
# 0         Amelia Smith (23.34652947149612)
# 1       Ka'iwi Schucht (33.30276974251637)
# 2         Amelia Smith (21.93414195595092)
# 3       Ka'iwi Schucht (36.55539643862576)
# 4         Brook Bauer (28.842259171681867)
# 5          Brook Bauer (28.64147527656869)
# 6      Brianna Sizemore (28.8347768278221)
# 7    Brianna Sizemore (28.620247353555268)
# 8     Corinne Quiggle (42.164965706910905)
# 9       Ka'iwi Schucht (36.91774905414632)
# 10          Sara Kovac (38.01089894206488)
# 11    Hunter Domanski (28.725069699402606)
# 12       Lina Bernier (28.214777476474794)
# 13           Sara Putt (43.98697950562183)
# 14      Jensyn Bledsoe (26.38282347797486)
# 15     Aubrey Cheffey (23.838816937118914)
# 16          Sara Kovac (40.04769242776744)
# 17  Frances Giedraitis (32.74189181858081)
# 18     Olivia Hallaran (38.91253722028222)
# 19         Iya Lindahl (47.92158984032913)
# 20    Courtney Schwan (45.957796364675715)
# 21    Corinne Quiggle (59.749766520506405)
# 22         Hailey Luke (49.34330172490732)
# 23      Dorina Klinger (38.81170874835384)
# 24      Jessalyn Kinlaw (46.6675816691132)
# 25       Bella Baumann (33.38691375954774)
# 26         Cadie Bates (48.74024977664164)
# 27        Anete Brinke (46.17618064392009)
# 28        Sammy Slater (60.08834218735609)
# 29         Emily Bible (48.68401380391899)
# 30          Sam Manley (56.23376586815501)
# 31       Kaitlyn Lines (25.56297418316292)
# 32     Courtney Bowen (48.589959031131286)
# 33     Megan Kruidhof (59.745384146439584)
# 34        Bailey Choy (38.527211319502655)
# 35         Amelia Smith (65.3648872029006)
# 36         Sammy Slater (69.7337185391601)
# 37        Sammy Slater (72.02898335460611)
# 38       Morgan Martin (74.69453990845882)

# %%
dict_adder_2018 = get_prior_year_player_rating_adders(df_top_players_2018)
df_start_rating_2019 = create_start_rating(dict_adder_2018, df_top_players_2018)
df_start_rating_2019.to_csv('2018_110_090_050_030_005/top_players_next_year_starting_rating.csv')

dict_start_ratings = df_start_rating_2019[['name','new_season_start_rating' ]].set_index('name').to_dict(orient='dict')['new_season_start_rating']
dict_start_ratings
# Out:
# {'Abbey Wilson': 25.0,
#  'Abby Waldburger': 25.0,
#  'Abigail Devido': 25.0,
#  'Abril Bustamante': 28.0,
#  'Addison Hermstad': 25.0,
#  'Adlee Van Winden': 25.0,
#  'Adore Anae': 25.0,
#  'Aeriel Horton': 27.0,
#  'Aeryn Owens': 25.0,
#  'Alaina Chacon': 25.0,
#  'Alanya Ryan': 25.0,
#  'Aleksandra Djordjevic': 25.0,
#  'Aleksandra Djuric': 25.0,
#  'Alex Holt': 25.0,
#  'Alex Kells': 25.0,
#  'Alexa Richardson': 25.0,
#  'Alexa Van Komen': 25.0,
#  'Alexandra Poletto': 25.0,
#  'Alexia Inman': 25.0,
#  'Alexis Filippone': 25.0,
#  'Alexis Patterson': 25.0,
#  'Ali Denney': 25.0,
#  'Ali Eager': 25.0,
#  'Allie Elson': 25.0,
#  'Allie Havers': 25.0,
#  'Allie Kemp': 25.0,
#  'Allison Beckman': 25.0,
#  'Allison Kantor': 25.0,
#  'Ally Barber': 25.0,
#  'Ally Carr': 25.0,
#  'Allyssah Fitterer': 25.0,
#  'Aly Brinkley': 25.0,
#  'Alyssa Cecil': 25.0,
#  'Amanda Carroll': 25.0,
#  'Amanda Silva': 25.0,
#  'Amber Gibson': 25.0,
#  'Amelia Smith': 25.0,
#  'Amie Held': 25.0,
#  'Amy Ozee': 25.0,
#  'Amy Weiss': 25.0,
#  'Anabela Sataric': 25.0,
#  'Andie Shelton': 25.0,
#  'Anete Brinke': 25.0,
#  'Anezka Szabo': 25.0,
#  'Anna Chin': 25.0,
#  'Anna Crabtree': 25.0,
#  'Anna Dalla Vecchia': 25.0,
#  'Anna McCreadie': 25.0,
#  'Anna Unnasch': 25.0,
#  'Annie Pringle': 25.0,
#  'Annika Albrecht': 25.0,
#  'Annika Van Gunst': 27.0,
#  'Ari Homayun': 25.0,
#  'Aristea Tontai': 25.0,
#  'Ashlan Cunningham': 25.0,
#  'Ashley Allmer': 25.0,
#  'Ashley Bauchert': 25.0,
#  'Ashley Clingan': 25.0,
#  'Ashley Delgado': 25.0,
#  'Ashley Glickert': 25.0,
#  'Ashley McGinn': 25.0,
#  'Ashley Slay': 25.0,
#  'Ashlyn Fleming': 25.0,
#  'Ashtin Olin': 25.0,
#  'Aubrey Cheffey': 25.0,
#  'Aubrey Ezell': 25.0,
#  'August Raskie': 25.0,
#  'Autumn Otto': 25.0,
#  'Autumn Russell': 25.0,
#  'Avei Logoleo': 25.0,
#  'Avery Arellano': 25.0,
#  'Avery Davis': 25.0,
#  'Bailey Banks': 25.0,
#  'Bailey Choy': 25.0,
#  'Bailey Smith': 25.0,
#  'Bella Baumann': 25.0,
#  'Berkeley Oblad': 25.0,
#  'Bethany Randall': 25.0,
#  'Bethany Salapek': 25.0,
#  'Blaire Register': 25.0,
#  'Blake Sharp': 25.0,
#  'Blessings Dunn': 25.0,
#  'Bozena Culo': 25.0,
#  'Brayden Gruenewald': 25.0,
#  'Breann Robinson': 25.0,
#  'Brennan Miller': 25.0,
#  'Briana Correa': 25.0,
#  'Brianna Doehrmann': 25.0,
#  'Brianna Sizemore': 25.0,
#  'Brianna Vega': 25.0,
#  'Briannah Mariner': 25.0,
#  'Brie Gathright': 25.0,
#  'Brigitte Murdock': 25.0,
#  'Brindl Langley': 25.0,
#  'Brittany Gillingham': 25.0,
#  'Brittany Pase': 25.0,
#  'Brittany Pellitteri': 25.0,
#  'Brittany Velez': 25.0,
#  'Brook Bauer': 25.0,
#  'Brooke Boiseau': 25.0,
#  'Brooke Burling': 25.0,
#  'Brooke Kuhlman': 25.0,
#  'Brooke Moore': 25.0,
#  'Brooke Riley': 25.0,
#  'Brooke Sassin': 25.0,
#  'Brooke Weiner': 25.0,
#  'Bryce Bark': 25.0,
#  'Brynn Montgomery': 25.0,
#  'Cadie Bates': 25.0,
#  'Caitlin Keefe': 25.0,
#  'Cali Thompson': 25.0,
#  'Callie Workman': 25.0,
#  'Camille Araujo': 25.0,
#  'Cammie Dorn': 25.0,
#  'Candice Denny': 25.0,
#  'Cara Sander': 25.0,
#  'Carey Williams': 25.0,
#  'Carina Hoff': 25.0,
#  'Carla Cahill': 25.0,
#  'Carly Beddingfield': 25.0,
#  'Carly Dehoog': 25.0,
#  'Carly Kan': 25.0,
#  'Carly Lowry': 25.0,
#  'Carly Perales': 25.0,
#  'Carly Scarborough': 25.0,
#  'Carly Schneider': 25.0,
#  'Caroline Cordes': 25.0,
#  'Caroline Finnell': 25.0,
#  'Caroline Schafer': 25.0,
#  'Caroline Skaff': 25.0,
#  'Caroline Waite': 25.0,
#  'Carolyn Cain': 25.0,
#  'Casey Justice': 25.0,
#  'Cassedi Simon': 25.0,
#  'Cassidy Rosso': 25.0,
#  'Cassie House': 25.0,
#  'Catherine Griffith': 25.0,
#  'Catherine Raquel': 25.0,
#  'Cecily Gable': 25.0,
#  'Chandler Clark': 25.0,
#  'Chaney Howard': 25.0,
#  'Chanti Holroyd': 25.0,
#  'Charis Ludtke': 25.0,
#  'Chesney McClellan': 25.0,
#  'Chloe Crappell': 25.0,
#  'Chloe Luyties': 25.0,
#  'Chloe Newton': 25.0,
#  'Chloe Reinig': 25.0,
#  'Chloe Simon': 25.0,
#  'Chloe Stitt': 25.0,
#  'Christina Mcafee': 25.0,
#  'Cianna Andrews': 25.0,
#  'Ciara Reistad': 25.0,
#  'Cierra Flood': 25.0,
#  'Cierra Simpson': 25.0,
#  'Claire Coppola': 27.0,
#  'Claire Darland': 25.0,
#  'Claire Doyle': 25.0,
#  'Claire Newlander': 25.0,
#  'Colene Hamilton': 25.0,
#  'Corinne Quiggle': 27.0,
#  'Courtney Bowen': 25.0,
#  'Courtney Miller': 25.0,
#  'Courtney Mullinax': 25.0,
#  'Courtney Schwan': 25.0,
#  'Courtney VanLiew': 25.0,
#  'Cristina Finan': 25.0,
#  'Dani Barton': 25.0,
#  'Daniella Molinari': 25.0,
#  'Danielle McCarson': 25.0,
#  'Danielle Wheeler': 25.0,
#  'Darby Dunn': 25.0,
#  'Deahna Kraft': 27.0,
#  'Delaney Driver': 25.0,
#  'Demi McInnis': 25.0,
#  'Desiree Sukhov': 25.0,
#  'Destiny Julye': 25.0,
#  'Devon May': 25.0,
#  'Devon Rachel': 25.0,
#  'Dora Beilin': 25.0,
#  'Dora Lulic': 25.0,
#  'Dorina Klinger': 25.0,
#  'Drew Hanneman': 25.0,
#  'Eastyn Baleto': 25.0,
#  'Eden Hawes': 25.0,
#  'Eighmy Dobbins': 25.0,
#  'Elise Zappia': 25.0,
#  'Elli Gibson': 25.0,
#  'Elli Merchant': 25.0,
#  'Ellyson Lundberg': 25.0,
#  'Emilee Wissmach': 25.0,
#  'Emily Baptista': 25.0,
#  'Emily Bible': 25.0,
#  'Emily Hansen': 25.0,
#  'Emily Hardesty': 25.0,
#  'Emily Lopes': 25.0,
#  'Emily Maglio': 27.0,
#  'Emily Martinez': 25.0,
#  'Emily Nenninger': 25.0,
#  'Emily Reinking': 25.0,
#  'Emily Sonny': 25.0,
#  'Emma Calle': 25.0,
#  'Emma Doud': 25.0,
#  'Emma Kirst': 25.0,
#  'Emmy Allen': 25.0,
#  'Erica Brok': 25.0,
#  'Erica Ronda': 25.0,
#  'Erika Zembyla': 25.0,
#  'Erin Bognar': 25.0,
#  'Erin Byrne': 25.0,
#  'Erin Indermill': 25.0,
#  'Erin Martin': 25.0,
#  'Erin Reineking': 25.0,
#  'Estefanie Bethancourt': 25.0,
#  'Eva Torruella': 25.0,
#  'Federica Frasca': 27.0,
#  'Fernanda Vido': 25.0,
#  'Forfeit 1': 25.0,
#  'Forfeit 2': 25.0,
#  'Frances Giedraitis': 25.0,
#  'Francesca Goncalves': 25.0,
#  'Franky Harrison': 25.0,
#  'Gabbi Moreno': 25.0,
#  'Gabby Love': 25.0,
#  'Gabriella Becerra': 25.0,
#  'Gabriella Johnston': 25.0,
#  'Gabrielle Dischler': 25.0,
#  'Georgia Johnson': 25.0,
#  'Gigi Hernandez': 25.0,
#  'Gina Tillis': 25.0,
#  'Ginny Gerig': 25.0,
#  'Giovanna Borgiotti': 25.0,
#  'Grace Campbell': 25.0,
#  'Grace Convey': 25.0,
#  'Grace Jarnagin': 25.0,
#  'Gracie Garanich': 25.0,
#  'Gretchen Reinert': 25.0,
#  'Hailey Devlin': 25.0,
#  'Hailey Harward': 25.0,
#  'Hailey Hughes': 25.0,
#  'Hailey Lindberg': 25.0,
#  'Hailey Luke': 27.0,
#  'Haleigh Nelson': 25.0,
#  'Haley Hallgren': 25.0,
#  'Haley Howell': 25.0,
#  'Haley Jared': 25.0,
#  'Haley Turner': 25.0,
#  'Halle Hunt': 25.0,
#  'Halle Parker': 25.0,
#  'Hannah Edelman': 25.0,
#  'Hannah Hubbard': 25.0,
#  'Hannah Kirk': 25.0,
#  'Hannah Manzanares': 25.0,
#  'Hannah Marchand': 25.0,
#  'Hannah Matt': 25.0,
#  'Hannah Meadows': 25.0,
#  'Hannah Rogers': 25.0,
#  'Hannah Sorensen': 25.0,
#  'Hannah Towne': 25.0,
#  'Hannah Zalopany': 25.0,
#  'Hanne De Schrijver': 25.0,
#  'Haven Hill': 25.0,
#  'Hayley Densberger': 25.0,
#  'Hayley Sturgeon': 25.0,
#  'Hayley Tippett': 25.0,
#  'Haylie Beck': 25.0,
#  'Heather Pembroke': 25.0,
#  'Heidi Dyer': 25.0,
#  'Helene Thelle': 25.0,
#  "Hi'ilawe Huddleston": 25.0,
#  'Holland Ponthieux': 25.0,
#  'Hunter Domanski': 25.0,
#  'Ivy Reynolds': 25.0,
#  'Iya Lindahl': 25.0,
#  'Izzy Carey': 25.0,
#  'JM Lewandowski': 25.0,
#  'Jacey Smith': 25.0,
#  'Jaelyn Greene': 25.0,
#  'Jaime Thomas': 25.0,
#  'Jamie Hirai': 25.0,
#  'Jamie McQuarrie': 25.0,
#  'Jamie Stivers': 25.0,
#  'Jamie Walsh': 25.0,
#  'Janell Walley': 25.0,
#  'Jasmine Schmidt': 25.0,
#  'Jaymee-Lee Bulda': 25.0,
#  'Jazz Sweat': 25.0,
#  'Jenna Belton': 25.0,
#  'Jenna Krenek': 25.0,
#  'Jenna Panning': 25.0,
#  'Jennifer Laird': 25.0,
#  'Jensen Allen': 25.0,
#  'Jensyn Bledsoe': 25.0,
#  'Jess Vastine': 25.0,
#  'Jessalyn Kinlaw': 25.0,
#  'Jessica Clark': 25.0,
#  'Jessica Gaffney': 25.0,
#  'Jessica Hall': 25.0,
#  'Jessica Johnson': 25.0,
#  'Jessica Manley': 25.0,
#  'Jessica Martinez': 25.0,
#  'Jessica Stansfield': 25.0,
#  'Jessica Wooten': 27.0,
#  'Jessie Prichard': 25.0,
#  'Jessie Wachtman': 25.0,
#  'Jillian Bergeson': 25.0,
#  'Jo Kremer': 25.0,
#  'Jonny Baham': 25.0,
#  'Jordan Anderson': 25.0,
#  'Jordan Ferrari': 25.0,
#  'Jordan Jones': 25.0,
#  'Jordan Schumacher': 25.0,
#  'Jordan Terral': 25.0,
#  'Jordan Westendorf': 25.0,
#  'Jordyn Miller': 25.0,
#  'Josie Cole': 25.0,
#  'Joy Dennis': 25.0,
#  'Julia Golbeck': 25.0,
#  'Julia Hanson': 25.0,
#  'Julia Lewkowicz': 25.0,
#  'Julia Mannisto': 25.0,
#  'Julia Topor': 25.0,
#  'Julie Varga': 25.0,
#  "Ka'iwi Schucht": 27.0,
#  'Kacey Nady': 25.0,
#  'Kacy Ogden': 25.0,
#  'Kahlee York': 25.0,
#  'Kaila Dorish': 25.0,
#  'Kaitlan Krivdo': 25.0,
#  'Kaitlyn Grice': 25.0,
#  'Kaitlyn Lines': 25.0,
#  'Kaitlynn Zdroik': 25.0,
#  'Kaity Bailey': 25.0,
#  'Kali Fluke': 25.0,
#  'Kalin Eske': 25.0,
#  'Kara Bajema': 25.0,
#  'Kara Woodard': 25.0,
#  'Karissa Rhoades': 25.0,
#  'Karlee Reynolds': 25.0,
#  'Kassidy Naone': 25.0,
#  'Kat Anderson': 25.0,
#  'Kate Baldwin': 25.0,
#  'Kate Formico': 25.0,
#  'Kate Novack': 25.0,
#  'Katelyn Carballo': 25.0,
#  'Katelyn Mueller': 25.0,
#  'Katelyn Theiss': 25.0,
#  'Katherine Puisis': 25.0,
#  'Kathryn Plummer': 25.0,
#  'Katie Barker': 25.0,
#  'Katie Cross': 25.0,
#  'Katie Friesen': 25.0,
#  'Katie Gavin': 25.0,
#  'Katie Horton': 27.0,
#  'Katie Krawczyk': 25.0,
#  'Katie McCullough': 25.0,
#  'Katie Pyles': 25.0,
#  'Katie Sarber': 25.0,
#  'Katie Sato': 25.0,
#  'Katie Smith': 27.0,
#  'Katie Will': 25.0,
#  'Katinka Krahn': 25.0,
#  'Katja Ehlers': 25.0,
#  'Katrin Gotterba': 25.0,
#  'Katrina Kernochan': 25.0,
#  'Katya Silveira': 25.0,
#  'Kayla Armer': 25.0,
#  'Kayla Frear': 25.0,
#  'Kayla Gallant': 25.0,
#  'Kayla Long': 25.0,
#  'Kayla Walker': 25.0,
#  'Kayla Whetstone': 25.0,
#  'Kaylee McClure': 25.0,
#  'Kaylee Taff': 25.0,
#  'Kaylie Mchugh': 27.0,
#  'Kaylie Milton': 25.0,
#  'Kekai Whitford': 25.0,
#  'Kelli Iverson': 25.0,
#  'Kellie Hughes': 25.0,
#  'Kellie Pernula': 25.0,
#  'Kelly Hunter': 25.0,
#  'Kelsey Knudsen': 25.0,
#  'Kelsey Larsen': 25.0,
#  'Kendall Bosse': 25.0,
#  'Kendall Murr': 25.0,
#  'Kendyl Brennan': 25.0,
#  'Kenley Adams': 25.0,
#  'Kenna Hanses': 25.0,
#  'Kennedy Kurtz': 25.0,
#  'Kennedy Madison': 25.0,
#  'Kennedy Shelstead': 25.0,
#  'Kenzie Koerber': 25.0,
#  'Kenzie Maloney': 25.0,
#  'Kiley Lewis': 25.0,
#  'Kim Krutsinger': 25.0,
#  'Kimberly Schnars': 25.0,
#  'Kimmy Gardiner': 25.0,
#  'Kinga Windisch': 25.0,
#  'Krissy Mummey': 25.0,
#  'Krista Hernandez': 25.0,
#  'Kristen Castellanos': 25.0,
#  'Kristen Mead': 25.0,
#  'Kristen Nuss': 27.0,
#  'Kristey Markle': 25.0,
#  'Kristine Hjembo': 25.0,
#  'Kristy Wieser': 25.0,
#  'Kristyna Adamcikova': 25.0,
#  'Kwyn Johnson': 25.0,
#  'Kyla Augustine': 25.0,
#  'Kyla Manning': 25.0,
#  'Kylee Johnson': 25.0,
#  'Kylie Keeling': 25.0,
#  'Kyra Hanawahine': 25.0,
#  'Lainy Thomas': 25.0,
#  'Lan Nguyen': 25.0,
#  'Lana Brown': 25.0,
#  'Laura Gauta': 25.0,
#  'Laura Leap': 25.0,
#  'Laura Parts': 25.0,
#  'Laurel Weaver': 25.0,
#  'Lauren Conati': 25.0,
#  'Lauren Durham': 25.0,
#  'Lauren Freed': 25.0,
#  'Lauren McMurray': 25.0,
#  'Lauren Naatz': 25.0,
#  'Lauren Orlich': 25.0,
#  'Lauren Page': 25.0,
#  'Lauren Petersen': 25.0,
#  'Lauren Rokey': 25.0,
#  'Lauren Sproule': 25.0,
#  'Lauren Stivrins': 25.0,
#  'Lauren Twitty': 25.0,
#  'Lauren Walker': 25.0,
#  'Lea Monkhouse': 27.0,
#  'Leah Hardeman': 25.0,
#  'Leah Perri': 25.0,
#  'Lela Mcintosh': 25.0,
#  'Lexi Ham': 25.0,
#  'Lexie Rawls': 25.0,
#  'Lilly Kessler': 25.0,
#  'Lily Justine': 27.0,
#  'Lina Bernier': 25.0,
#  'Lindsey Calvin': 25.0,
#  'Lindsey Knudsen': 25.0,
#  'Lindsey Vander Weide': 25.0,
#  'Liz Allen': 25.0,
#  'Liz Reich': 25.0,
#  'Logan Manusky': 25.0,
#  'Luiza Andrade': 25.0,
#  'Lydia Dimke': 25.0,
#  'Lyndi Scholl': 25.0,
#  'Lynsey Wright': 25.0,
#  'MC Rogers': 25.0,
#  'Mac May': 25.0,
#  'Macey Hayden': 25.0,
#  'Macie Tendrich': 25.0,
#  'Mackenzie Allen': 25.0,
#  'Mackenzie Dear': 25.0,
#  'Mackenzie Morris': 25.0,
#  'Mackenzie Rombach': 25.0,
#  'Mackenzie Swan': 25.0,
#  'Mackenzie Walker': 25.0,
#  'Macy Gordon': 25.0,
#  'Macy Jerger': 25.0,
#  'Madalyn Roh': 27.0,
#  'Maddie Beck': 25.0,
#  'Maddie Cloutier': 25.0,
#  'Maddie Dilfer': 25.0,
#  'Maddie Fella': 25.0,
#  'Maddie Gordon': 25.0,
#  'Maddie Irwin': 25.0,
#  'Maddie Leiphardt': 25.0,
#  'Maddie Ligon': 25.0,
#  'Maddie Micheletti': 25.0,
#  'Maddy Kline': 25.0,
#  'Madeline Mertz': 27.0,
#  'Madi Fitzsimmons': 25.0,
#  'Madi Relaz': 25.0,
#  'Madi Wilkerson': 25.0,
#  'Madi Yeomans': 25.0,
#  'Madilyn McCarty': 25.0,
#  'Madison Besterfield': 25.0,
#  'Madison Dueck': 25.0,
#  'Madison Fitzpatrick': 25.0,
#  'Madison Green': 25.0,
#  'Madison Miller': 25.0,
#  'Maggie Scott': 25.0,
#  'Maile Sellers': 25.0,
#  'Maja Kaiser': 25.0,
#  'Makenna Martin': 25.0,
#  'Makenzie Kesler': 25.0,
#  'Mallory Mattingly': 25.0,
#  'Mallory Waggoner': 25.0,
#  'Mandi Orellana': 25.0,
#  'Margherita Bianchin': 27.0,
#  'Mariana Dal Pozzo': 25.0,
#  'Mariana De Paula Silva': 25.0,
#  'Marina Chavez': 25.0,
#  'Marine Hall-Poirier': 25.0,
#  'Marisa Ramsey': 25.0,
#  'Marissa Rogers': 25.0,
#  'Mary Hernandez': 25.0,
#  'Mattie Johnson': 25.0,
#  'Mattison Degarmo': 25.0,
#  'Maxine Walsh': 25.0,
#  'Maya Daukas': 25.0,
#  'Maya Watkins': 25.0,
#  'Maybeth Sandercox': 25.0,
#  'Maycie LaBass': 25.0,
#  'McKayla Ferris': 25.0,
#  'McKenna Webster': 25.0,
#  'McKenzie Schwan': 25.0,
#  'Mckala Rhodes': 25.0,
#  'Meagan Carter': 25.0,
#  'Meagan McCall': 25.0,
#  'Megan Davenport': 25.0,
#  'Megan Kruidhof': 25.0,
#  'Megan McGrath': 25.0,
#  'Megan McNamara': 27.0,
#  'Megan Muret': 25.0,
#  'Megan Nash': 25.0,
#  'Melissa Powell': 25.0,
#  'Mercedes Pacheco': 25.0,
#  'Mia Mason': 25.0,
#  'Mia Merino': 25.0,
#  'Mia Rivera': 25.0,
#  'Michelle Gajdka': 25.0,
#  'Mikaela Mosquera': 25.0,
#  'Mikaela Nocetti': 25.0,
#  'Mikayla Vivens': 25.0,
#  'Mima Mirkovic': 27.0,
#  'Molly McBain': 25.0,
#  'Molly Scheel': 25.0,
#  'Molly Turner': 25.0,
#  'Morgan Dees': 25.0,
#  'Morgan Esters': 25.0,
#  'Morgan Hentz': 25.0,
#  'Morgan Hughes': 25.0,
#  'Morgan Kendrick': 25.0,
#  'Morgan Martin': 27.0,
#  'Morgan Robinson': 25.0,
#  'Nandyala Gama': 25.0,
#  'Naomi Overstreet': 25.0,
#  'Natalia Giron': 25.0,
#  'Natalie Anselmo': 25.0,
#  'Natalie Braun': 25.0,
#  'Natalie Honzovicova': 25.0,
#  'Natalie Robinson': 25.0,
#  'Nele Barber': 27.0,
#  'Ngozi Nwabuzoh': 25.0,
#  'Nicci Reinking': 25.0,
#  'Nickeisha Williams': 25.0,
#  'Nicole DeBolt': 25.0,
#  'Nicole Decker': 25.0,
#  'Nicole Grant': 25.0,
#  'Nicole Lott': 25.0,
#  'Nicole McNamara': 27.0,
#  'Nicole Navarro': 25.0,
#  'Nicolette Pinkney': 25.0,
#  'Nikki Esposito': 25.0,
#  'Nikki Lyons': 25.0,
#  'Nina Korfhage': 25.0,
#  'Nora Buvarp Lavik': 25.0,
#  'Olivia Hallaran': 25.0,
#  'Olivia Lee': 25.0,
#  'Olivia Lohmeier': 25.0,
#  'Olivia Macdonald': 25.0,
#  'Olivia Petnicki': 25.0,
#  'Olivia Powers': 25.0,
#  'Olivia Rook': 25.0,
#  'Olivia Stasevich': 25.0,
#  'Paige Dreeuws': 25.0,
#  'Paige Swinney': 25.0,
#  'Paris Cosley': 25.0,
#  'Payton Chang': 25.0,
#  'Payton Rund': 25.0,
#  'Peri Green': 25.0,
#  'Peyton Boutwell': 25.0,
#  'Phoebe Grace': 25.0,
#  "Pi'ikea Clemens": 25.0,
#  'Quinci Birker': 25.0,
#  'Rachel Evans': 25.0,
#  'Rachel Kuhn': 25.0,
#  'Rachel Nieto': 27.0,
#  'Rachel Noble': 25.0,
#  'Rachel Young': 25.0,
#  'Raeann Greisen': 25.0,
#  'Raquel Rooney': 25.0,
#  'Reagan Evans': 25.0,
#  'Rebecca Brown': 25.0,
#  'Rebecca Ingram': 25.0,
#  'Rebekah Brodbeck': 25.0,
#  'Rhyan Rand': 25.0,
#  'Riana Brennan': 25.0,
#  'Riley Young': 25.0,
#  'Rio Frohoff': 25.0,
#  'Roni Long': 25.0,
#  'Ronika Stone': 25.0,
#  'Ryann Thomison': 25.0,
#  'Sabrina Blackwell': 25.0,
#  'Sabryn Roberts': 25.0,
#  'Sadie Anderson': 25.0,
#  'Sallianne Napolitano': 25.0,
#  'Sam Bogdan': 25.0,
#  'Sam Brinkmann': 25.0,
#  'Sam Gott': 25.0,
#  'Sam Manley': 25.0,
#  'Samantha Drechsel': 25.0,
#  'Samantha Harris': 25.0,
#  'Samantha Plaster': 25.0,
#  'Sami Slaughter': 25.0,
#  'Sammee Thomas': 25.0,
#  'Sammy Slater': 27.0,
#  'Sara Boothe': 25.0,
#  'Sara Kovac': 25.0,
#  'Sara Putt': 25.0,
#  'Sara Watanabe': 25.0,
#  'Sarah Chase': 25.0,
#  'Sarah Davis': 25.0,
#  'Sarah Demmer': 25.0,
#  'Sarah Falk': 25.0,
#  'Sarah Garrow': 25.0,
#  'Sarah Kelly': 25.0,
#  'Sarah Savoca': 25.0,
#  'Sarah Sponcil': 27.0,
#  'Sarah Stewart': 25.0,
#  'Sasha Karelov': 27.0,
#  'Savannah Siegrist': 25.0,
#  'Savannah Slattery': 25.0,
#  'Savvy Simo': 25.0,
#  'Selina Marolf': 25.0,
#  'Shannon Levinson': 25.0,
#  'Shannon Richardson': 25.0,
#  'Shannon Williams': 25.0,
#  'Shawnee De Oliveira': 25.0,
#  'Shayla Schmidt': 25.0,
#  'Shaylee Befus': 25.0,
#  'Shayne Mcpherson': 25.0,
#  'Shelby Babowicz': 25.0,
#  'Shelby Holmes': 25.0,
#  'Shelby Ladewig': 25.0,
#  'Sienna Young': 25.0,
#  'Sierra Ellett': 25.0,
#  'Sjea Anderson': 25.0,
#  'Skye Southwick': 25.0,
#  'Skylar Caputo': 25.0,
#  'Skylar Wine': 25.0,
#  'Skyler Takeda': 25.0,
#  'Snowy Burnam': 25.0,
#  'Sofia Resendiz': 25.0,
#  'Sophie Peel': 25.0,
#  'Stephanie Pollnow': 25.0,
#  'Stephany Purdue': 25.0,
#  'Summer Avery': 25.0,
#  'Sunniva Helland-Hansen': 25.0,
#  'Sunny Villapando': 27.0,
#  'Sydney Haynes': 25.0,
#  'Sydney Palmer': 25.0,
#  'Sydney Wicks': 25.0,
#  'Taija Thomas': 25.0,
#  'Tani Stephens': 25.0,
#  'Tanner Gauthier': 25.0,
#  'Tarin Mergener': 25.0,
#  'Taryn Griffey': 25.0,
#  'Tatiana San Juan': 25.0,
#  'Tatum Ballard': 25.0,
#  'Tawnee Luafalemana': 25.0,
#  'Taylor Agost': 25.0,
#  'Taylor Bradley': 25.0,
#  'Taylor Foley': 25.0,
#  'Taylor Fricano': 25.0,
#  'Taylor Jarzombek': 25.0,
#  'Taylor Meyer': 25.0,
#  'Taylor Nelson': 25.0,
#  'Taylor Odom': 25.0,
#  'Taylor Poncetta': 25.0,
#  'Teegan Van Gunst': 27.0,
#  'Terese Cannon': 25.0,
#  'Tessie Powers': 25.0,
#  'Thaliana Grajeda': 25.0,
#  'Tia Miric': 25.0,
#  'Tiffany Creamer': 25.0,
#  'Tina Graudina': 27.0,
#  'Tori Hinojosa': 25.0,
#  'Tori Reiser': 25.0,
#  'Torrey Van Winden': 25.0,
#  'Tressa Buckland': 25.0,
#  'Trish Koutsoukos': 25.0,
#  'Vanessa Freire': 27.0,
#  'Veronica Corcoran': 25.0,
#  'Veronica Nederend': 25.0,
#  'Veronica Snelling': 25.0,
#  'Victoria Corcoran': 25.0,
#  'Victoria Paranagua': 27.0,
#  'Willow Johnson': 25.0,
#  'Yasmin Tan': 25.0,
#  'Zana Muno': 25.0,
#  'Zoi Konstantopoulou': 25.0}

# %%
df_start_rating_2019[df_start_rating_2019['new_season_start_rating'] > 25]
# Out:
#                    name  last_season_end_rating  new_season_start_rating
# 0      Abril Bustamante               92.430350                     28.0
# 1       Nicole McNamara               86.113556                     27.0
